# %%
import urllib.request
import os
import tarfile  
from keras.datasets import imdb
from keras.preprocessing import sequence 
from keras.preprocessing.text import Tokenizer 
import re
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
import pandas as pd
import numpy as np
from numpy.random import RandomState
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import  linear_model
from sklearn.linear_model import LinearRegression
from sklearn import  linear_model
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from scipy.stats import laplace
from math import log
from random import random
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import binarize
import itertools
import random
from scipy.optimize import minimize
import csv
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import operator
from random import seed
from random import randrange
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn.metrics import log_loss
from keras.models import Sequential
from keras.layers import Dense,Flatten,Embedding,SimpleRNN

# %%
def rm_tags(text):
    re_tag = re.compile(r'<[^>]+>')
    return re_tag.sub('',text)
def read_files(filetype):
    path = "./aclImdb/"
    file_list=[]
    positive_path=path + filetype+"/pos/"
    for f in os.listdir(positive_path):
        file_list+=[positive_path+f]   
    negative_path=path + filetype+"/neg/"
    for f in os.listdir(negative_path):
        file_list+=[negative_path+f]      
    print('read',filetype, 'files:',len(file_list))      
    all_labels = ([1] * 12500 + [0] * 12500)    
    all_texts  = []
    for fi in file_list:
        with open(fi,encoding='utf8') as file_input:
            filelines = file_input.readlines()       
            all_texts += [rm_tags(filelines[0])]         
    return all_labels,all_texts

# %%
url="http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"
filepath="aclImdb_v1.tar.gz"
if not os.path.isfile(filepath):
    result=urllib.request.urlretrieve(url,filepath)
    print('downloaded:',result)
if not os.path.exists("aclImdb"):
    tfile = tarfile.open("aclImdb_v1.tar.gz", 'r:gz')
    result=tfile.extractall('.')

# %%
y_train, x_train = read_files('train')
y_test, x_test = read_files('test')

token = Tokenizer(num_words=2000)
token.fit_on_texts(x_train)

x_train_seq = token.texts_to_sequences(x_train)
x_test_seq = token.texts_to_sequences(x_test)
 
x_train_v = sequence.pad_sequences(x_train_seq,maxlen=100)
x_test_v =  sequence.pad_sequences(x_test_seq,maxlen=100)
# Out:
# read train files: 25000
# read test files: 25000

# %%
x_train_seq
# Out:
# [[14,
#   3,
#   16,
#   11,
#   210,
#   53,
#   1157,
#   46,
#   248,
#   22,
#   3,
#   172,
#   4,
#   902,
#   14,
#   10,
#   1524,
#   833,
#   3,
#   16,
#   117,
#   912,
#   6,
#   161,
#   158,
#   6,
#   3,
#   132,
#   1,
#   105,
#   6,
#   31,
#   1551,
#   102,
#   14,
#   1604,
#   1,
#   1787,
#   13,
#   3,
#   564],
#  [1158,
#   185,
#   16,
#   1058,
#   15,
#   800,
#   1584,
#   17,
#   30,
#   298,
#   4,
#   1313,
#   13,
#   3,
#   180,
#   17,
#   639,
#   15,
#   3,
#   1827,
#   33,
#   6,
#   5,
#   985,
#   14,
#   37,
#   30,
#   1,
#   5,
#   604,
#   1,
#   135,
#   15,
#   22,
#   51,
#   69,
#   1989,
#   1,
#   1305,
#   224,
#   6,
#   399,
#   6,
#   1216,
#   13,
#   17,
#   50,
#   1094,
#   79,
#   3,
#   943,
#   30,
#   3,
#   19,
#   1,
#   346,
#   1862,
#   179,
#   62,
#   376,
#   1,
#   582,
#   3,
#   2,
#   374,
#   22,
#   3,
#   172,
#   2,
#   6,
#   83,
#   249,
#   13,
#   3,
#   564,
#   1247,
#   1,
#   16,
#   6,
#   750,
#   3,
#   1652,
#   4,
#   892,
#   2,
#   1,
#   17,
#   47,
#   3,
#   444,
#   19,
#   1,
#   114,
#   30,
#   1,
#   6,
#   364,
#   4,
#   834,
#   121,
#   69,
#   30,
#   163,
#   484,
#   33,
#   3,
#   273,
#   15,
#   301,
#   237,
#   35],
#  [3,
#   1151,
#   44,
#   18,
#   13,
#   12,
#   385,
#   57,
#   510,
#   169,
#   2,
#   1,
#   60,
#   151,
#   11,
#   58,
#   93,
#   68,
#   136,
#   42,
#   4,
#   57,
#   92,
#   5,
#   63,
#   10,
#   170,
#   12,
#   1,
#   385,
#   132,
#   15,
#   1,
#   392,
#   9,
#   442,
#   1,
#   2,
#   1,
#   133,
#   32,
#   14,
#   5,
#   1],
#  [41,
#   3,
#   676,
#   543,
#   5,
#   864,
#   580,
#   7,
#   3,
#   747,
#   30,
#   842,
#   2,
#   64,
#   358,
#   9,
#   416,
#   36,
#   300,
#   4,
#   3,
#   16,
#   9,
#   140,
#   24,
#   73,
#   344,
#   3,
#   444,
#   721,
#   270,
#   85,
#   5,
#   1891,
#   513,
#   36,
#   97,
#   61,
#   723,
#   5,
#   3,
#   157,
#   508,
#   1,
#   157,
#   549,
#   1506,
#   12,
#   276,
#   1059,
#   17,
#   43,
#   5,
#   376,
#   227,
#   365,
#   6,
#   111,
#   770,
#   257,
#   50,
#   1,
#   60,
#   6,
#   1863,
#   38,
#   33,
#   29,
#   467,
#   301,
#   237,
#   6,
#   3,
#   1458,
#   1031,
#   179,
#   6,
#   912,
#   1,
#   23,
#   389,
#   2,
#   22,
#   26,
#   358,
#   15,
#   1,
#   337,
#   1739,
#   3,
#   1739,
#   11,
#   6,
#   5,
#   511,
#   21,
#   44,
#   330,
#   15,
#   8,
#   17,
#   20,
#   1235,
#   53,
#   1,
#   337,
#   1739,
#   3,
#   11,
#   1093,
#   21,
#   7,
#   1,
#   1238,
#   912,
#   2,
#   23,
#   4,
#   441,
#   1506,
#   30,
#   3,
#   4,
#   79,
#   23,
#   276,
#   1947,
#   1506,
#   294,
#   8,
#   641,
#   11,
#   26,
#   28,
#   1,
#   54,
#   91,
#   26,
#   94,
#   29,
#   389,
#   5,
#   1170,
#   94,
#   116,
#   1506,
#   11,
#   26,
#   66,
#   1891,
#   160,
#   7,
#   889,
#   2,
#   19,
#   3,
#   253,
#   6,
#   31,
#   400,
#   36,
#   1,
#   7,
#   59,
#   1,
#   358,
#   413,
#   408,
#   42,
#   64,
#   920,
#   4,
#   3,
#   576,
#   44,
#   870,
#   122,
#   1832,
#   68,
#   485,
#   120,
#   11,
#   9,
#   24,
#   31,
#   456,
#   9,
#   416,
#   36,
#   3,
#   29,
#   3,
#   11,
#   23,
#   1828,
#   17,
#   6,
#   1660,
#   36,
#   3,
#   1327,
#   1153,
#   1087,
#   18,
#   8,
#   6,
#   195,
#   2,
#   1902,
#   560,
#   163,
#   6,
#   77,
#   3,
#   5,
#   1,
#   1,
#   211,
#   25,
#   30,
#   689,
#   7,
#   1571,
#   1506,
#   1772,
#   3,
#   460,
#   997,
#   26,
#   43,
#   31,
#   77,
#   43,
#   3,
#   277,
#   4,
#   1964,
#   15,
#   137,
#   26,
#   19,
#   2,
#   5,
#   44,
#   21,
#   67,
#   5,
#   10,
#   16,
#   1,
#   92,
#   358,
#   78,
#   64,
#   21,
#   76,
#   63,
#   11,
#   8,
#   6,
#   40,
#   321,
#   2,
#   357,
#   1008,
#   13,
#   7,
#   1643,
#   60,
#   5,
#   846,
#   3,
#   7,
#   1956,
#   66,
#   846,
#   3,
#   151,
#   38,
#   103,
#   40,
#   35,
#   29,
#   1,
#   126,
#   4,
#   1,
#   18,
#   9,
#   12,
#   50,
#   103,
#   491,
#   68,
#   605,
#   29,
#   253,
#   81,
#   15,
#   2,
#   11,
#   12,
#   3,
#   83,
#   16,
#   83,
#   146,
#   9,
#   524,
#   24,
#   5,
#   542,
#   7,
#   97],
#  [21,
#   238,
#   28,
#   454,
#   120,
#   10,
#   30,
#   146,
#   17,
#   462,
#   668,
#   111,
#   66,
#   25,
#   19,
#   203,
#   292,
#   3,
#   172,
#   4,
#   693,
#   116,
#   1,
#   149,
#   2,
#   10,
#   6,
#   865,
#   57,
#   510,
#   119,
#   122,
#   41,
#   3,
#   818,
#   11,
#   10,
#   1288,
#   394,
#   2,
#   914,
#   119,
#   12,
#   1,
#   152,
#   11,
#   252,
#   2,
#   22,
#   28,
#   1044,
#   2,
#   34,
#   1244,
#   7,
#   144,
#   551,
#   56,
#   1,
#   358,
#   22,
#   83,
#   385,
#   119,
#   34,
#   612,
#   11,
#   41,
#   820,
#   4,
#   260,
#   9,
#   590,
#   40,
#   1,
#   1001,
#   8,
#   12,
#   46,
#   6,
#   53,
#   92,
#   636,
#   383,
#   542,
#   261,
#   11,
#   1557,
#   65,
#   228,
#   5,
#   78,
#   15,
#   8,
#   8,
#   12,
#   7,
#   1,
#   399,
#   54,
#   7,
#   10,
#   203,
#   292,
#   28,
#   1,
#   668,
#   170,
#   19,
#   9,
#   436,
#   32,
#   28,
#   212,
#   42,
#   19,
#   284,
#   45,
#   247,
#   1211,
#   14,
#   882],
#  [9,
#   215,
#   1,
#   16,
#   15,
#   103,
#   472,
#   258,
#   8,
#   12,
#   20,
#   13,
#   1090,
#   13,
#   9,
#   193,
#   8,
#   12,
#   243,
#   48,
#   7,
#   3,
#   16,
#   1705,
#   30,
#   472,
#   33,
#   67,
#   19,
#   986,
#   46,
#   12,
#   20,
#   3,
#   479,
#   34,
#   9,
#   120,
#   1,
#   472,
#   28,
#   419,
#   8,
#   46,
#   842,
#   77,
#   464,
#   1,
#   337,
#   2,
#   1728,
#   337,
#   4,
#   101,
#   834,
#   40,
#   1,
#   2,
#   790,
#   80,
#   919,
#   10,
#   16,
#   12,
#   89,
#   14,
#   358,
#   13,
#   137,
#   8,
#   12,
#   1106,
#   258,
#   9,
#   419,
#   8,
#   95,
#   1269,
#   9,
#   419,
#   1],
#  [330,
#   767,
#   1,
#   893,
#   870,
#   344,
#   45,
#   5,
#   45,
#   4,
#   125,
#   1634,
#   104,
#   41,
#   138,
#   21,
#   353,
#   395,
#   2,
#   41,
#   28,
#   84,
#   4,
#   10,
#   1575,
#   27,
#   178,
#   624,
#   155,
#   773,
#   85,
#   66,
#   8,
#   20,
#   25,
#   344,
#   3,
#   743,
#   9,
#   590,
#   29,
#   144,
#   33,
#   198,
#   10,
#   3,
#   1536,
#   38,
#   31,
#   613,
#   85,
#   96,
#   1,
#   82,
#   18,
#   122,
#   89,
#   25,
#   124,
#   14,
#   1,
#   1851,
#   1,
#   192,
#   127,
#   632,
#   320,
#   6,
#   83,
#   3,
#   894,
#   945,
#   5,
#   1,
#   899,
#   2,
#   1,
#   904,
#   19,
#   1,
#   6,
#   3,
#   1328,
#   1226,
#   28,
#   10,
#   741,
#   1575,
#   1,
#   677,
#   1258,
#   6,
#   396,
#   10,
#   6,
#   1258],
#  [10,
#   12,
#   3,
#   48,
#   18,
#   15,
#   3,
#   971,
#   745,
#   4,
#   115,
#   2,
#   9,
#   442,
#   1,
#   4,
#   1,
#   591,
#   2,
#   1,
#   4,
#   1,
#   523,
#   19,
#   1,
#   219,
#   69,
#   914,
#   2,
#   69,
#   522,
#   44,
#   46,
#   67,
#   97,
#   1511,
#   470,
#   24,
#   5,
#   131,
#   11,
#   1,
#   61,
#   1172,
#   1,
#   795,
#   219,
#   2,
#   64,
#   170,
#   47,
#   40,
#   28,
#   80,
#   4,
#   28,
#   9,
#   58,
#   115,
#   5,
#   63,
#   3,
#   16,
#   117,
#   28,
#   4,
#   130,
#   22,
#   614,
#   36,
#   7,
#   143,
#   109,
#   1,
#   18,
#   7,
#   1297,
#   4,
#   90,
#   1229,
#   2,
#   90,
#   1892,
#   4,
#   1,
#   85,
#   3,
#   66,
#   717,
#   290,
#   5,
#   23,
#   38,
#   37,
#   442,
#   1,
#   18,
#   2,
#   8,
#   834,
#   1668,
#   5,
#   57,
#   521],
#  [89,
#   99,
#   12,
#   1,
#   486,
#   4,
#   1,
#   905,
#   18,
#   4,
#   1,
#   342,
#   533,
#   30,
#   129,
#   1,
#   285,
#   533,
#   22,
#   1,
#   439,
#   120,
#   8,
#   28,
#   2,
#   1,
#   82,
#   103,
#   22,
#   694,
#   1,
#   6,
#   36,
#   3,
#   972,
#   17,
#   27,
#   15,
#   3,
#   48,
#   985,
#   121,
#   2,
#   1,
#   232,
#   49,
#   617,
#   13,
#   1336,
#   22,
#   571,
#   170,
#   1,
#   1,
#   18,
#   2,
#   1,
#   533,
#   587,
#   512,
#   5,
#   24,
#   23,
#   213,
#   13,
#   6,
#   1,
#   627,
#   7,
#   1,
#   26,
#   1772,
#   10,
#   388,
#   548,
#   288,
#   7,
#   3,
#   1407,
#   17,
#   1,
#   157,
#   484,
#   6,
#   31,
#   50,
#   26,
#   43,
#   53,
#   26,
#   86,
#   43,
#   1889,
#   45,
#   274,
#   34,
#   26,
#   712,
#   23,
#   318,
#   26,
#   3,
#   388,
#   1629,
#   2,
#   26,
#   43,
#   3,
#   48,
#   740,
#   2,
#   23,
#   1126,
#   512,
#   26,
#   43,
#   3,
#   222,
#   4,
#   50,
#   23,
#   6,
#   30,
#   1,
#   1563,
#   6,
#   5,
#   63,
#   85,
#   23,
#   1230,
#   1,
#   6,
#   50,
#   1974,
#   888,
#   15,
#   40,
#   23,
#   636,
#   559,
#   8,
#   5,
#   21,
#   5,
#   838,
#   1,
#   17,
#   4,
#   1,
#   1788,
#   5,
#   26,
#   1832,
#   3,
#   128,
#   36,
#   19,
#   3,
#   7,
#   439,
#   120,
#   8,
#   28,
#   6,
#   3,
#   2,
#   1070,
#   548,
#   35,
#   1,
#   651,
#   33,
#   6,
#   19,
#   3,
#   966,
#   1181,
#   30,
#   23,
#   1103,
#   669,
#   6,
#   439,
#   1,
#   122,
#   1852,
#   2,
#   424,
#   33,
#   6,
#   639,
#   4,
#   1227,
#   5,
#   179,
#   2,
#   512,
#   6,
#   571,
#   7,
#   1,
#   719,
#   29,
#   10,
#   209,
#   1,
#   61,
#   161,
#   169,
#   4,
#   1,
#   110,
#   4,
#   1,
#   697,
#   61,
#   2,
#   18,
#   13,
#   162,
#   3,
#   11,
#   26,
#   66,
#   371,
#   3,
#   143,
#   414,
#   4,
#   35,
#   3,
#   1212,
#   99,
#   11,
#   3,
#   414,
#   4,
#   26,
#   6,
#   143,
#   9,
#   524,
#   1630,
#   1,
#   92,
#   5,
#   1,
#   6,
#   1,
#   294,
#   1,
#   4,
#   3,
#   560,
#   2,
#   27,
#   54,
#   13,
#   7,
#   1,
#   997,
#   1537,
#   129,
#   26,
#   43,
#   5,
#   357,
#   3,
#   14,
#   3,
#   374,
#   4,
#   1916,
#   14,
#   23,
#   26,
#   654,
#   3,
#   1729,
#   1047,
#   4,
#   80,
#   582,
#   1554,
#   13,
#   3,
#   17,
#   303,
#   181,
#   251,
#   13,
#   31,
#   304,
#   13,
#   3,
#   329,
#   33,
#   6,
#   29,
#   321,
#   15,
#   13,
#   3,
#   1852,
#   33,
#   60,
#   283,
#   23,
#   29,
#   23,
#   899,
#   50,
#   23,
#   318,
#   283,
#   52,
#   2,
#   484,
#   13,
#   3,
#   181,
#   128,
#   33,
#   43,
#   3,
#   617,
#   109,
#   13,
#   285,
#   533,
#   787,
#   130,
#   101,
#   293,
#   42,
#   5,
#   64,
#   1,
#   232,
#   1948,
#   15,
#   2,
#   6,
#   17,
#   1682,
#   723,
#   8,
#   12,
#   3,
#   789,
#   52,
#   5,
#   1,
#   905,
#   2,
#   69,
#   286,
#   145],
#  [14,
#   3,
#   128,
#   5,
#   969,
#   11,
#   26,
#   3,
#   116,
#   10,
#   18,
#   6,
#   3,
#   5,
#   3,
#   18,
#   44,
#   27,
#   355,
#   969,
#   49,
#   91,
#   377,
#   27,
#   96,
#   131,
#   11,
#   109,
#   66,
#   111,
#   25,
#   1,
#   168,
#   99,
#   823,
#   137,
#   14,
#   8,
#   43,
#   1672,
#   174,
#   5,
#   1,
#   372,
#   644],
#  [57,
#   975,
#   6,
#   7,
#   10,
#   18,
#   392,
#   3,
#   29,
#   1,
#   289,
#   1726,
#   1974,
#   55,
#   43,
#   3,
#   1328,
#   132,
#   15,
#   7,
#   3,
#   221,
#   49,
#   1613,
#   19,
#   37,
#   29,
#   256,
#   57,
#   959,
#   598,
#   7,
#   1,
#   18,
#   9,
#   24,
#   5,
#   131,
#   11,
#   9,
#   100,
#   8,
#   6,
#   3,
#   303,
#   16,
#   723,
#   158,
#   2,
#   1288,
#   810],
#  [14,
#   157,
#   178,
#   1264,
#   541,
#   13,
#   27,
#   4,
#   1,
#   1877,
#   7,
#   1691,
#   5,
#   122,
#   1692,
#   720,
#   1,
#   4,
#   1,
#   405,
#   3,
#   1568,
#   235,
#   13,
#   3,
#   157,
#   33,
#   123,
#   37,
#   114,
#   5,
#   7,
#   3,
#   1,
#   206,
#   1576,
#   3,
#   1140,
#   13,
#   1,
#   378,
#   37,
#   920,
#   40,
#   395,
#   3,
#   546,
#   7,
#   1004,
#   4,
#   1,
#   756,
#   6,
#   3,
#   143,
#   510,
#   1691,
#   499,
#   16,
#   519,
#   1,
#   1539,
#   3,
#   2,
#   466,
#   13,
#   3,
#   923,
#   33,
#   712,
#   3,
#   1644,
#   972,
#   40,
#   1813,
#   3,
#   3,
#   4,
#   1236,
#   2,
#   162,
#   37,
#   18,
#   13,
#   928,
#   2,
#   1,
#   122,
#   1255,
#   123,
#   3,
#   1328,
#   1295,
#   4,
#   37,
#   1350,
#   213,
#   35,
#   3,
#   780,
#   4,
#   1,
#   258,
#   10,
#   427,
#   123,
#   1645,
#   1,
#   868,
#   1162,
#   4,
#   1100,
#   1003,
#   1514,
#   2,
#   563,
#   41,
#   127,
#   30,
#   53,
#   811,
#   3,
#   2,
#   414,
#   4,
#   1,
#   16,
#   51,
#   1,
#   107,
#   765,
#   7,
#   59,
#   345,
#   368,
#   2,
#   1,
#   11,
#   368,
#   66,
#   97,
#   44,
#   32,
#   1135,
#   291,
#   79,
#   3,
#   600,
#   34,
#   32,
#   66,
#   389,
#   64,
#   13,
#   27,
#   990,
#   1143,
#   459,
#   262,
#   139,
#   15,
#   3,
#   4,
#   1367,
#   2,
#   1902,
#   384,
#   4,
#   402,
#   1990,
#   195,
#   625,
#   2,
#   304,
#   599,
#   22,
#   1240,
#   19,
#   1,
#   274,
#   317,
#   7,
#   1,
#   369,
#   701,
#   962,
#   1730,
#   1653,
#   785,
#   1399,
#   4,
#   1,
#   43,
#   3,
#   223,
#   13,
#   3,
#   998,
#   33,
#   43,
#   23,
#   515,
#   30,
#   3,
#   4,
#   1166,
#   50,
#   26,
#   29,
#   3,
#   1706,
#   5,
#   357,
#   1,
#   2,
#   733,
#   13,
#   423,
#   823,
#   14,
#   1691,
#   1274,
#   7,
#   16,
#   447],
#  [50,
#   9,
#   1605,
#   10,
#   16,
#   5,
#   102,
#   8,
#   9,
#   695,
#   11,
#   8,
#   12,
#   20,
#   166,
#   5,
#   25,
#   3,
#   16,
#   300,
#   9,
#   193,
#   4,
#   8,
#   13,
#   3,
#   4,
#   631,
#   117,
#   290,
#   6,
#   166,
#   5,
#   74,
#   3,
#   617,
#   2,
#   21,
#   120,
#   47,
#   8,
#   948,
#   118,
#   47,
#   9,
#   147,
#   12,
#   3,
#   1729,
#   213,
#   7,
#   796,
#   1,
#   1625,
#   11,
#   26,
#   12,
#   9,
#   382,
#   10,
#   16,
#   44,
#   125,
#   42,
#   15,
#   1,
#   1008,
#   2,
#   177,
#   5,
#   102,
#   3,
#   48,
#   202,
#   18],
#  [41,
#   250,
#   5,
#   131,
#   514,
#   134,
#   613,
#   3,
#   18,
#   6,
#   34,
#   1127,
#   35,
#   1,
#   557,
#   9,
#   82,
#   381,
#   633,
#   1,
#   1649,
#   426,
#   138,
#   575,
#   68,
#   8,
#   58,
#   25,
#   3,
#   83,
#   18,
#   7,
#   4,
#   11,
#   8,
#   464,
#   51,
#   11,
#   470,
#   122,
#   24,
#   1,
#   1428,
#   5,
#   161,
#   63,
#   8,
#   14,
#   542,
#   91,
#   27,
#   247,
#   133,
#   263,
#   139,
#   1,
#   4,
#   57,
#   715,
#   9,
#   215,
#   11,
#   32,
#   65,
#   1026,
#   1,
#   284,
#   761,
#   4,
#   10,
#   18,
#   59,
#   142,
#   572,
#   1259,
#   14,
#   84,
#   1,
#   625,
#   6,
#   4,
#   3,
#   1378,
#   1132,
#   2,
#   486,
#   11,
#   31,
#   150,
#   1858,
#   1034,
#   96,
#   111,
#   2,
#   1382,
#   4,
#   1,
#   625,
#   9,
#   211,
#   680,
#   8,
#   42,
#   13,
#   226,
#   2,
#   748,
#   1,
#   87,
#   1378,
#   1248,
#   4,
#   10,
#   18,
#   13,
#   3,
#   33,
#   51,
#   750,
#   1,
#   1109,
#   401,
#   995,
#   7,
#   1,
#   1649,
#   426,
#   142,
#   3,
#   7,
#   1,
#   188,
#   11,
#   3,
#   83,
#   66,
#   216,
#   680,
#   1661,
#   3,
#   18,
#   129,
#   26,
#   43,
#   3,
#   172,
#   4,
#   335,
#   35,
#   31,
#   572,
#   1014,
#   173,
#   2,
#   3,
#   163,
#   33,
#   945,
#   47,
#   1,
#   61,
#   734,
#   17,
#   5,
#   24,
#   491,
#   1,
#   366,
#   162,
#   171,
#   132,
#   138,
#   4,
#   930,
#   2,
#   21,
#   66,
#   216,
#   111,
#   131,
#   11,
#   87,
#   104,
#   58,
#   111,
#   56,
#   532,
#   137,
#   3,
#   151,
#   4,
#   21,
#   132,
#   99,
#   132,
#   45,
#   1585,
#   45,
#   113,
#   223,
#   4,
#   1109,
#   1233,
#   11,
#   299,
#   125,
#   241,
#   1,
#   163,
#   1360,
#   43,
#   65,
#   3,
#   192,
#   2,
#   217,
#   607,
#   13,
#   226,
#   13,
#   9,
#   66,
#   10,
#   18,
#   6,
#   20,
#   51,
#   4,
#   8,
#   17,
#   514,
#   5,
#   1270,
#   3,
#   163,
#   746,
#   1,
#   4,
#   23,
#   607,
#   154,
#   28,
#   1,
#   190,
#   2,
#   1926,
#   4,
#   1144,
#   221,
#   3,
#   143,
#   1299,
#   1233,
#   5,
#   25,
#   254,
#   141,
#   7,
#   10,
#   18,
#   1620,
#   179,
#   589,
#   15,
#   3,
#   109,
#   4,
#   64,
#   201,
#   2,
#   91,
#   122,
#   1031,
#   72,
#   36,
#   398,
#   304,
#   104,
#   101,
#   22,
#   344,
#   830,
#   5,
#   54,
#   5,
#   735,
#   495,
#   533,
#   589,
#   84,
#   32,
#   78,
#   2,
#   194,
#   85,
#   109,
#   6,
#   3,
#   1729,
#   56,
#   1346,
#   1892,
#   4,
#   402,
#   872,
#   7,
#   10,
#   18,
#   1,
#   112,
#   72,
#   4,
#   10,
#   61,
#   291,
#   50,
#   80,
#   735,
#   50,
#   32,
#   1773,
#   7,
#   10,
#   18,
#   32,
#   78,
#   34,
#   13,
#   774,
#   80,
#   20,
#   1424,
#   141,
#   30,
#   1,
#   188,
#   11,
#   32,
#   22,
#   392,
#   101,
#   225,
#   1014,
#   2,
#   152,
#   36,
#   665,
#   487,
#   2,
#   5,
#   1136,
#   54,
#   327,
#   722,
#   1,
#   179,
#   32,
#   24,
#   5,
#   131,
#   22,
#   1398,
#   38,
#   4,
#   929,
#   8,
#   28,
#   262,
#   176,
#   15,
#   1,
#   4,
#   1046,
#   631,
#   50,
#   21,
#   164,
#   29,
#   1,
#   152,
#   571,
#   38,
#   1,
#   83,
#   809,
#   30,
#   587,
#   8,
#   182,
#   676,
#   11,
#   137,
#   3,
#   18,
#   25,
#   51,
#   750,
#   1546,
#   275,
#   72,
#   4,
#   47,
#   162,
#   1,
#   1649,
#   426,
#   47,
#   8,
#   6,
#   12,
#   1,
#   54,
#   805,
#   8,
#   12,
#   89,
#   7,
#   221,
#   10,
#   543,
#   5,
#   10,
#   427,
#   11,
#   1783,
#   68,
#   1682,
#   4,
#   57,
#   201,
#   1543,
#   80,
#   735,
#   4,
#   1,
#   7,
#   1297,
#   4,
#   678,
#   2,
#   224,
#   17,
#   194,
#   20,
#   1,
#   9,
#   1447,
#   7,
#   38,
#   373,
#   1,
#   164,
#   4,
#   1,
#   1213,
#   1,
#   2,
#   460,
#   1271,
#   486,
#   4,
#   1,
#   112,
#   2,
#   1,
#   443,
#   955,
#   140,
#   74,
#   461,
#   1,
#   4,
#   97,
#   410,
#   33,
#   52,
#   7,
#   38,
#   746,
#   10,
#   996,
#   4,
#   54,
#   7,
#   931,
#   9,
#   63,
#   542,
#   7,
#   10,
#   9,
#   63,
#   85,
#   9,
#   215,
#   1,
#   178,
#   2,
#   3,
#   18,
#   36,
#   1,
#   1649,
#   426,
#   1078,
#   1,
#   178,
#   14,
#   85,
#   8,
#   367,
#   6,
#   14,
#   49,
#   4,
#   10,
#   543,
#   588,
#   63,
#   1,
#   325,
#   111,
#   1408,
#   1361,
#   7,
#   1,
#   477,
#   308,
#   1949,
#   713,
#   1,
#   997,
#   1,
#   997,
#   4,
#   2],
#  [418,
#   10,
#   210,
#   1,
#   364,
#   743,
#   379,
#   41,
#   1040,
#   13,
#   247,
#   11,
#   10,
#   6,
#   1258,
#   1,
#   1409,
#   3,
#   181,
#   1660,
#   676,
#   128,
#   27,
#   247,
#   2,
#   1056,
#   86,
#   19,
#   7,
#   28,
#   11,
#   278,
#   11,
#   21,
#   39,
#   187,
#   1212,
#   95,
#   75,
#   8,
#   1050,
#   7,
#   1515,
#   14,
#   1,
#   181,
#   128,
#   44,
#   60,
#   31,
#   273,
#   96,
#   25,
#   394,
#   14,
#   11,
#   61,
#   1,
#   81,
#   103,
#   7,
#   1,
#   78,
#   1,
#   61,
#   15,
#   2,
#   7,
#   1,
#   551,
#   4,
#   1,
#   181,
#   345,
#   1,
#   178,
#   6,
#   721,
#   2,
#   1,
#   6,
#   30,
#   1,
#   738,
#   174,
#   3,
#   79,
#   1789,
#   52,
#   907,
#   7,
#   931,
#   1173,
#   14,
#   255,
#   2,
#   312],
#  [10,
#   16,
#   6,
#   69,
#   869,
#   39,
#   90,
#   1185,
#   41,
#   20,
#   3,
#   565,
#   41,
#   20,
#   976,
#   5,
#   25,
#   17,
#   90,
#   3,
#   190,
#   565,
#   7,
#   57,
#   178,
#   2,
#   57,
#   71,
#   22,
#   136,
#   10,
#   6,
#   3,
#   83,
#   16,
#   14,
#   68],
#  [10,
#   6,
#   3,
#   18,
#   11,
#   12,
#   51,
#   69,
#   220,
#   9,
#   65,
#   552,
#   1845,
#   852,
#   133,
#   8,
#   12,
#   7,
#   361,
#   2,
#   24,
#   73,
#   1061,
#   14,
#   90,
#   761,
#   5,
#   1,
#   163,
#   2,
#   28,
#   1,
#   152,
#   1,
#   692,
#   173,
#   516,
#   47,
#   55,
#   883,
#   5,
#   189,
#   10,
#   5,
#   1,
#   346,
#   13,
#   312,
#   331,
#   129,
#   1631,
#   1,
#   1563,
#   4,
#   1,
#   18,
#   6,
#   118,
#   31,
#   476,
#   288,
#   15,
#   37,
#   105,
#   108,
#   55,
#   65,
#   20,
#   220,
#   3,
#   172,
#   4,
#   153,
#   50,
#   10,
#   18,
#   12,
#   89,
#   55,
#   43,
#   175,
#   1,
#   607,
#   1405,
#   4,
#   37,
#   9,
#   12,
#   29,
#   37,
#   235,
#   9,
#   336,
#   506,
#   1,
#   18,
#   57,
#   1229,
#   7,
#   109,
#   2,
#   2,
#   240,
#   3,
#   124,
#   410,
#   14,
#   8,
#   3,
#   83,
#   745,
#   1833,
#   741,
#   1,
#   18,
#   761,
#   8,
#   34,
#   28,
#   66,
#   353],
#  [3,
#   795,
#   139,
#   2,
#   631,
#   59,
#   1676,
#   1662,
#   1113,
#   49,
#   1662,
#   1874,
#   2,
#   1949,
#   56,
#   49,
#   1662,
#   754,
#   52,
#   208,
#   1234,
#   49,
#   1662,
#   2,
#   830,
#   8,
#   6,
#   20,
#   13,
#   38,
#   13,
#   52,
#   7,
#   17,
#   8,
#   127,
#   6,
#   963,
#   158,
#   205,
#   1569,
#   13,
#   676,
#   13,
#   323,
#   1300,
#   46,
#   22,
#   45,
#   352,
#   135,
#   59,
#   1470,
#   1,
#   632,
#   132,
#   117,
#   32,
#   74,
#   45,
#   14,
#   64,
#   515,
#   2,
#   1,
#   1274,
#   5,
#   153,
#   77,
#   158,
#   6,
#   609,
#   1525,
#   2,
#   789,
#   52,
#   609,
#   155,
#   132,
#   6,
#   1,
#   1048,
#   132,
#   15,
#   1526,
#   402,
#   1686,
#   35,
#   1,
#   564,
#   1800,
#   197,
#   2,
#   1,
#   150,
#   1096,
#   128,
#   28,
#   7,
#   28,
#   10,
#   6,
#   3,
#   83,
#   789,
#   52,
#   5,
#   52,
#   7,
#   2,
#   6,
#   175,
#   1746,
#   50,
#   38,
#   20],
#  [606,
#   47,
#   9,
#   131,
#   1,
#   16,
#   12,
#   317,
#   9,
#   240,
#   3,
#   662,
#   333,
#   2,
#   9,
#   24,
#   328,
#   28,
#   301,
#   200,
#   1145,
#   2,
#   9,
#   430,
#   19,
#   5,
#   328,
#   49,
#   9,
#   240,
#   146,
#   19,
#   4,
#   1903,
#   738,
#   10,
#   16,
#   3,
#   1238,
#   70,
#   8,
#   140,
#   24,
#   28,
#   209,
#   5,
#   3,
#   385,
#   16,
#   9,
#   442,
#   1,
#   222,
#   151,
#   34,
#   47,
#   6,
#   7,
#   54,
#   55,
#   6,
#   127,
#   150,
#   36,
#   55,
#   6,
#   7,
#   1,
#   1145,
#   80,
#   33,
#   768,
#   328,
#   49,
#   70,
#   462,
#   1145,
#   22,
#   40,
#   1,
#   647,
#   4,
#   9,
#   24,
#   328,
#   28,
#   4,
#   94,
#   2,
#   9,
#   100,
#   6,
#   399,
#   2,
#   11,
#   12,
#   399,
#   9,
#   254,
#   527,
#   4,
#   1,
#   16,
#   9,
#   442,
#   1,
#   1122,
#   515,
#   2,
#   74,
#   9,
#   442,
#   1,
#   9,
#   1,
#   731,
#   542,
#   8,
#   12,
#   62,
#   385,
#   9,
#   1460,
#   21,
#   136,
#   63,
#   8,
#   233,
#   80,
#   33,
#   24,
#   73,
#   120,
#   159,
#   4,
#   3,
#   47,
#   3,
#   48,
#   16,
#   6,
#   2,
#   499,
#   40,
#   136,
#   63,
#   8,
#   8,
#   199,
#   20,
#   25,
#   729,
#   1512,
#   17,
#   90,
#   62,
#   3,
#   48,
#   16],
#  [10,
#   6,
#   27,
#   4,
#   1,
#   82,
#   104,
#   9,
#   66,
#   373,
#   38,
#   275,
#   1,
#   82,
#   27,
#   613,
#   1,
#   303,
#   239,
#   4,
#   18,
#   70,
#   3,
#   549,
#   79,
#   1,
#   178,
#   4,
#   563,
#   2,
#   67,
#   71,
#   408,
#   3,
#   113,
#   223,
#   4,
#   2,
#   28,
#   10,
#   69,
#   1845,
#   79,
#   3,
#   2,
#   71,
#   74,
#   10,
#   9,
#   88,
#   120,
#   44,
#   90,
#   367,
#   1153,
#   14,
#   358,
#   17,
#   9,
#   100,
#   8,
#   12,
#   51,
#   641,
#   51,
#   158,
#   2,
#   217,
#   9,
#   777,
#   50,
#   3,
#   18,
#   3,
#   66,
#   24,
#   3,
#   48,
#   126,
#   2,
#   90,
#   84,
#   171,
#   105,
#   211,
#   24,
#   3,
#   649,
#   126,
#   56,
#   44,
#   8,
#   932,
#   907,
#   20,
#   3,
#   410,
#   17,
#   10,
#   12,
#   606,
#   26,
#   327,
#   267,
#   1821,
#   2,
#   32,
#   383,
#   8,
#   7,
#   11,
#   92,
#   28,
#   10,
#   6,
#   39,
#   3,
#   90,
#   3,
#   48,
#   16,
#   31,
#   138,
#   157,
#   51,
#   1295,
#   2,
#   9,
#   136],
#  [10,
#   18,
#   6,
#   286,
#   315,
#   580,
#   14,
#   1337,
#   1140,
#   4,
#   304,
#   8,
#   148,
#   547,
#   11,
#   148,
#   613,
#   23,
#   1186,
#   2,
#   22,
#   1046,
#   114,
#   132,
#   7,
#   3,
#   715,
#   15,
#   3,
#   333,
#   13,
#   5,
#   722,
#   718,
#   704,
#   115,
#   686,
#   6,
#   1512,
#   4,
#   301,
#   7,
#   931],
#  [9,
#   12,
#   160,
#   149,
#   150,
#   50,
#   10,
#   119,
#   12,
#   19,
#   244,
#   30,
#   226,
#   8,
#   12,
#   57,
#   510,
#   1,
#   152,
#   67,
#   51,
#   12,
#   39,
#   1487,
#   9,
#   39,
#   656,
#   1,
#   284,
#   1114,
#   668,
#   32,
#   156,
#   24,
#   1159,
#   1716,
#   32,
#   39,
#   65,
#   1731,
#   402,
#   1950,
#   1677,
#   1,
#   339,
#   152,
#   67,
#   51,
#   48,
#   7,
#   64,
#   51,
#   860,
#   46,
#   12,
#   3,
#   48,
#   61,
#   7,
#   253,
#   386,
#   29,
#   1,
#   54,
#   46,
#   67,
#   53,
#   314,
#   297,
#   38,
#   34,
#   1,
#   225,
#   12,
#   1403,
#   5,
#   25,
#   48,
#   2,
#   1,
#   101,
#   67,
#   83,
#   46,
#   12,
#   53,
#   534,
#   36,
#   7,
#   81,
#   283,
#   32,
#   156,
#   349,
#   5,
#   93,
#   3,
#   972,
#   171,
#   237,
#   231,
#   5,
#   93,
#   3,
#   634,
#   119,
#   9,
#   541,
#   382,
#   10,
#   244,
#   119,
#   5,
#   1808,
#   11,
#   36,
#   48,
#   534],
#  [1970,
#   155,
#   16,
#   11,
#   140,
#   25,
#   79,
#   3,
#   79,
#   830,
#   2,
#   7,
#   1,
#   459,
#   4,
#   1,
#   5,
#   119,
#   610,
#   1,
#   114,
#   4,
#   1941,
#   10,
#   16,
#   6,
#   34,
#   375,
#   2,
#   1198,
#   7,
#   108,
#   113,
#   49,
#   70,
#   3,
#   1673,
#   121,
#   4,
#   1,
#   454,
#   75,
#   16,
#   352,
#   705,
#   1980,
#   35,
#   11,
#   8,
#   20,
#   60,
#   1024,
#   5,
#   11,
#   18,
#   7,
#   1297,
#   4,
#   456,
#   17,
#   72,
#   4,
#   822,
#   1220,
#   1068,
#   1,
#   168,
#   400,
#   13,
#   226,
#   13,
#   3,
#   879,
#   196,
#   1,
#   1458,
#   129,
#   3,
#   2,
#   3,
#   1487,
#   402,
#   666,
#   4,
#   539,
#   4,
#   1,
#   576,
#   347,
#   33,
#   6,
#   51,
#   770,
#   19,
#   1,
#   521,
#   1,
#   18,
#   12,
#   89,
#   14,
#   358,
#   34,
#   1208,
#   35,
#   45,
#   116,
#   2,
#   3,
#   1158,
#   5,
#   131,
#   21,
#   66,
#   855,
#   40,
#   380,
#   1,
#   56,
#   43,
#   3,
#   428,
#   4,
#   1458,
#   5,
#   1107,
#   52,
#   23,
#   1,
#   955,
#   108,
#   56,
#   49,
#   1134,
#   70,
#   17,
#   13,
#   3,
#   121,
#   21,
#   78,
#   74,
#   3,
#   150,
#   1663,
#   103,
#   358,
#   1221,
#   7,
#   3,
#   1277,
#   466,
#   13,
#   3,
#   4,
#   3,
#   1015,
#   3,
#   1086,
#   904,
#   33,
#   210,
#   5,
#   24,
#   37,
#   201,
#   1147,
#   904,
#   1147,
#   98,
#   67,
#   190,
#   7,
#   14,
#   3,
#   133,
#   2,
#   4,
#   260,
#   13,
#   1,
#   627,
#   29,
#   1,
#   126,
#   14,
#   1896,
#   1,
#   33,
#   501,
#   42,
#   5,
#   25,
#   1,
#   48,
#   229,
#   534,
#   36,
#   1004,
#   126,
#   5,
#   164,
#   36,
#   1458,
#   952,
#   3,
#   962,
#   866,
#   1222,
#   1438,
#   35,
#   320,
#   5,
#   320,
#   45,
#   523,
#   11,
#   76,
#   93,
#   1,
#   7,
#   1904,
#   1,
#   962,
#   164,
#   30,
#   659,
#   3,
#   954,
#   89,
#   52,
#   4,
#   341,
#   1864,
#   1116,
#   38,
#   721,
#   132,
#   21,
#   66,
#   428,
#   4,
#   371,
#   117,
#   32,
#   67,
#   1199,
#   35,
#   85,
#   1,
#   22,
#   1806,
#   2,
#   45,
#   4,
#   1,
#   87,
#   17,
#   314,
#   297,
#   153,
#   122,
#   7,
#   3,
#   1458,
#   16,
#   41,
#   129,
#   11,
#   1,
#   18,
#   1195,
#   68,
#   116,
#   41,
#   39,
#   14,
#   108,
#   89,
#   1262,
#   6,
#   161,
#   1,
#   168,
#   33,
#   834,
#   1,
#   178,
#   7,
#   2,
#   1053,
#   1,
#   287,
#   154,
#   10,
#   12,
#   3,
#   51,
#   670,
#   163,
#   7,
#   1,
#   1005,
#   2,
#   202,
#   1147,
#   509,
#   18,
#   132,
#   35,
#   1,
#   2,
#   30,
#   1,
#   54,
#   4,
#   26,
#   12,
#   238,
#   5,
#   74,
#   1,
#   153,
#   9,
#   58,
#   131,
#   11,
#   10,
#   6,
#   23,
#   87,
#   16,
#   122,
#   38,
#   243,
#   1,
#   27,
#   26,
#   558,
#   1,
#   87,
#   15,
#   2,
#   199,
#   24,
#   416,
#   49,
#   652,
#   144,
#   15,
#   1,
#   18,
#   29,
#   358,
#   1,
#   16,
#   43,
#   3,
#   239,
#   4,
#   5,
#   1,
#   92,
#   8,
#   12,
#   89,
#   11,
#   1,
#   1754,
#   38,
#   480,
#   38,
#   243,
#   32,
#   22,
#   169,
#   4,
#   1,
#   249,
#   2,
#   44,
#   1,
#   16,
#   65,
#   73,
#   252,
#   611,
#   8,
#   583,
#   24,
#   948,
#   59,
#   6,
#   613,
#   134,
#   822,
#   16,
#   26,
#   5,
#   24,
#   249,
#   15,
#   1,
#   814,
#   2,
#   383,
#   8,
#   1,
#   767,
#   23,
#   1265,
#   4,
#   375,
#   667,
#   80,
#   2,
#   15,
#   28,
#   41,
#   6,
#   161,
#   5,
#   1,
#   1097,
#   4,
#   134,
#   71,
#   102,
#   98,
#   36,
#   10,
#   59,
#   6,
#   5,
#   63,
#   152,
#   7,
#   967,
#   725,
#   19,
#   479,
#   20,
#   1120,
#   630,
#   4,
#   159,
#   81,
#   70,
#   250,
#   1274,
#   830,
#   470,
#   10,
#   52,
#   46,
#   15,
#   705,
#   1980,
#   2,
#   8,
#   4,
#   1,
#   83,
#   13,
#   27,
#   4,
#   1,
#   87,
#   1458,
#   962,
#   98,
#   122,
#   84,
#   1,
#   16,
#   268,
#   34,
#   1212,
#   21,
#   66,
#   74,
#   116,
#   1,
#   61,
#   2,
#   39,
#   24,
#   249,
#   145,
#   534,
#   74,
#   40,
#   2,
#   1271,
#   11,
#   2,
#   15,
#   3,
#   14,
#   256,
#   1,
#   577,
#   5,
#   93,
#   1,
#   16,
#   1905,
#   42,
#   28,
#   1,
#   2,
#   1539,
#   3,
#   364,
#   1147,
#   11,
#   234,
#   74,
#   3,
#   223,
#   14,
#   45,
#   4,
#   1,
#   388,
#   17,
#   6,
#   1,
#   82,
#   16,
#   9,
#   76,
#   122,
#   1490,
#   15,
#   1,
#   50,
#   64,
#   375,
#   842,
#   559,
#   94,
#   15,
#   68,
#   14,
#   3,
#   10,
#   6,
#   534,
#   14,
#   1,
#   2,
#   27,
#   4,
#   1,
#   87,
#   980,
#   4,
#   1941,
#   5,
#   122,
#   25,
#   5,
#   160,
#   160,
#   41,
#   40,
#   743,
#   231,
#   95,
#   192,
#   17,
#   33,
#   21,
#   60,
#   212,
#   183,
#   276,
#   2,
#   470,
#   243,
#   136,
#   42,
#   15,
#   3,
#   1827,
#   19,
#   57,
#   389],
#  [5,
#   28,
#   1,
#   1981,
#   19,
#   10,
#   1507,
#   9,
#   58,
#   24,
#   5,
#   131,
#   10,
#   16,
#   6,
#   286,
#   315,
#   34,
#   8,
#   12,
#   89,
#   7,
#   34,
#   47,
#   1,
#   1596,
#   7,
#   1,
#   16,
#   12,
#   613,
#   1,
#   168,
#   1596,
#   4,
#   90,
#   54,
#   80,
#   33,
#   156,
#   1176,
#   4,
#   1,
#   58,
#   100,
#   11,
#   10,
#   16,
#   6,
#   3,
#   1865,
#   1074,
#   5,
#   1,
#   678,
#   197,
#   313,
#   491,
#   804,
#   59,
#   6,
#   89,
#   14,
#   259,
#   54,
#   204,
#   146,
#   8,
#   123,
#   164,
#   186,
#   1,
#   60,
#   169,
#   4,
#   1,
#   16,
#   6,
#   1,
#   1596,
#   59,
#   170,
#   12,
#   116,
#   1084,
#   149,
#   7,
#   1,
#   497,
#   17,
#   1,
#   745,
#   11,
#   6,
#   1409,
#   7,
#   10,
#   18,
#   6,
#   51,
#   971,
#   2,
#   46,
#   6,
#   39,
#   34,
#   72,
#   5,
#   131,
#   17,
#   9,
#   5,
#   131,
#   8,
#   14,
#   1091,
#   4,
#   8,
#   34,
#   136,
#   42,
#   2,
#   63,
#   10,
#   18,
#   44,
#   21,
#   88,
#   36,
#   1,
#   745,
#   11,
#   8,
#   91,
#   21,
#   24,
#   1336,
#   11,
#   355,
#   45,
#   687],
#  [3,
#   1634,
#   4,
#   1917,
#   10,
#   16,
#   712,
#   4,
#   103,
#   157,
#   778,
#   101,
#   1228,
#   2,
#   33,
#   195,
#   5,
#   25,
#   1,
#   289,
#   229,
#   7,
#   1,
#   7,
#   1,
#   517,
#   1115,
#   2,
#   67,
#   143,
#   80,
#   147,
#   10,
#   6,
#   3,
#   4,
#   64,
#   444,
#   19,
#   3,
#   293,
#   118,
#   26,
#   78,
#   8,
#   41,
#   127,
#   3,
#   1200,
#   4,
#   1779,
#   35,
#   1,
#   14,
#   59,
#   26,
#   873,
#   800,
#   6,
#   614,
#   129,
#   13,
#   1444,
#   183,
#   1,
#   168,
#   54,
#   13,
#   1,
#   1864,
#   295,
#   321,
#   163,
#   691,
#   65,
#   3,
#   83,
#   14,
#   1,
#   805,
#   34,
#   1288,
#   129,
#   2,
#   8,
#   1676,
#   3,
#   1353,
#   608,
#   35,
#   1945,
#   3,
#   181,
#   6,
#   29,
#   23,
#   13,
#   2,
#   283,
#   170,
#   47,
#   3,
#   1090,
#   280,
#   26,
#   12,
#   13,
#   1206,
#   190,
#   2,
#   29,
#   207,
#   175,
#   1295,
#   180,
#   6,
#   1,
#   115,
#   598,
#   195,
#   1,
#   1008,
#   22,
#   364,
#   4,
#   109,
#   2,
#   1700,
#   1,
#   1094,
#   29,
#   3,
#   698,
#   1060,
#   1021,
#   107,
#   398,
#   8,
#   6,
#   20,
#   31,
#   770,
#   16,
#   5,
#   165,
#   17,
#   6,
#   69,
#   286,
#   263,
#   42,
#   14],
#  [13,
#   87,
#   121,
#   21,
#   234,
#   121,
#   106,
#   319,
#   1643,
#   987,
#   121,
#   1,
#   21,
#   199,
#   690,
#   90,
#   3,
#   48,
#   16,
#   17,
#   13,
#   21,
#   234,
#   24,
#   106,
#   19,
#   370,
#   32,
#   1975,
#   234,
#   24,
#   3,
#   1069,
#   29,
#   1,
#   126,
#   2,
#   32,
#   39,
#   238,
#   126,
#   1,
#   16,
#   15,
#   1,
#   1069,
#   15,
#   53,
#   3,
#   38,
#   228,
#   17,
#   19,
#   1,
#   200,
#   27,
#   408,
#   244,
#   50,
#   32,
#   22,
#   17,
#   154,
#   9,
#   131,
#   49,
#   50,
#   1016,
#   1439,
#   7,
#   1,
#   1687,
#   38,
#   337,
#   319,
#   32,
#   215,
#   86,
#   2,
#   1439,
#   35,
#   341,
#   150,
#   554,
#   38,
#   17,
#   84,
#   553,
#   143,
#   400,
#   50,
#   32,
#   28,
#   22,
#   29,
#   1,
#   126,
#   50,
#   38,
#   290,
#   1,
#   121,
#   1016,
#   2,
#   1401,
#   1187,
#   29,
#   86,
#   2,
#   133,
#   155,
#   1097,
#   736,
#   6,
#   90,
#   17,
#   20,
#   13,
#   3,
#   13,
#   1,
#   150,
#   640,
#   121,
#   86,
#   2,
#   642,
#   15,
#   1016,
#   2,
#   9,
#   11,
#   89,
#   1,
#   16,
#   273,
#   3,
#   113,
#   223,
#   217,
#   17,
#   1,
#   1177,
#   38,
#   255,
#   140,
#   121,
#   89,
#   3,
#   1097,
#   121,
#   2,
#   2,
#   81,
#   11,
#   184,
#   553,
#   15,
#   461,
#   46,
#   7,
#   1,
#   141,
#   1558],
#  [9,
#   193,
#   10,
#   16,
#   12,
#   158,
#   41,
#   3,
#   249,
#   20,
#   5,
#   25,
#   619,
#   611,
#   16,
#   40,
#   27,
#   1597,
#   19,
#   109,
#   115,
#   2,
#   69,
#   1906,
#   35,
#   1,
#   1706,
#   5,
#   1,
#   308,
#   702,
#   1706,
#   1750,
#   294,
#   3,
#   229,
#   33,
#   12,
#   30,
#   7,
#   3,
#   401,
#   30,
#   3,
#   332,
#   819,
#   1338,
#   30,
#   303,
#   1502,
#   2,
#   1503,
#   50,
#   23,
#   332,
#   86,
#   42,
#   19,
#   1,
#   886,
#   26,
#   211,
#   846,
#   5,
#   14,
#   305,
#   15,
#   159,
#   17,
#   1,
#   19,
#   109,
#   11,
#   23,
#   1927,
#   43,
#   86,
#   11,
#   2,
#   31,
#   750,
#   644,
#   4,
#   1374,
#   2,
#   988,
#   1991,
#   2,
#   34,
#   1,
#   890,
#   44,
#   21,
#   768,
#   106,
#   10,
#   16,
#   2,
#   21,
#   353,
#   3,
#   634,
#   208,
#   115,
#   61,
#   91,
#   9,
#   541,
#   382,
#   1,
#   128],
#  [4,
#   1,
#   576,
#   347,
#   65,
#   3,
#   172,
#   5,
#   408,
#   52,
#   5,
#   56,
#   154,
#   1,
#   632,
#   895,
#   1693,
#   82,
#   97,
#   293,
#   19,
#   4,
#   1,
#   576,
#   347,
#   23,
#   439,
#   2,
#   725,
#   52,
#   3,
#   308,
#   1272,
#   5,
#   59,
#   107,
#   98,
#   561,
#   5,
#   2,
#   329,
#   57,
#   16,
#   145,
#   821,
#   11,
#   97,
#   185,
#   18,
#   58,
#   1,
#   7,
#   1,
#   71,
#   7,
#   5,
#   102,
#   71,
#   67,
#   15,
#   3,
#   1234,
#   2,
#   48,
#   859,
#   18,
#   445,
#   431,
#   1,
#   348,
#   6,
#   360,
#   2,
#   4,
#   260,
#   1,
#   365,
#   1,
#   173,
#   17,
#   4,
#   1,
#   576,
#   347,
#   1383,
#   859,
#   434,
#   701,
#   1239,
#   17,
#   50,
#   41,
#   10,
#   701,
#   21,
#   66,
#   691,
#   63,
#   117,
#   115,
#   1772,
#   8,
#   291,
#   492,
#   7,
#   3,
#   311,
#   1,
#   247,
#   2,
#   13,
#   3,
#   5,
#   23,
#   1148,
#   591,
#   29,
#   310,
#   26,
#   1300,
#   4,
#   723,
#   42,
#   4,
#   154,
#   10,
#   1085,
#   186,
#   23,
#   591,
#   6,
#   320,
#   5,
#   337,
#   7,
#   3,
#   1274,
#   30,
#   326,
#   31,
#   1731,
#   5,
#   38,
#   4,
#   23,
#   1032,
#   113,
#   52,
#   7,
#   31,
#   13,
#   3,
#   859,
#   2,
#   9,
#   100,
#   41,
#   49,
#   5,
#   1891,
#   125,
#   70,
#   189,
#   7,
#   3,
#   1274,
#   30,
#   17,
#   91,
#   170,
#   142,
#   3,
#   334,
#   1918,
#   4,
#   1,
#   4,
#   109,
#   85,
#   334,
#   3,
#   1918,
#   7,
#   5,
#   3,
#   132,
#   1231,
#   683,
#   345,
#   9,
#   424,
#   825,
#   19,
#   312,
#   34,
#   1,
#   537,
#   283,
#   52,
#   9,
#   338,
#   1,
#   168,
#   7,
#   57,
#   201,
#   360,
#   348,
#   185,
#   18,
#   53,
#   194,
#   1357,
#   424,
#   825,
#   67,
#   35,
#   157,
#   14,
#   3,
#   54,
#   13,
#   3,
#   955,
#   445,
#   3,
#   172,
#   4,
#   1,
#   16,
#   6,
#   266,
#   7,
#   576,
#   669,
#   34,
#   221,
#   3,
#   83,
#   851,
#   4,
#   42,
#   2,
#   1061,
#   14,
#   1,
#   1141,
#   17,
#   1,
#   101,
#   22,
#   2,
#   1,
#   16,
#   6,
#   8,
#   90,
#   348,
#   7,
#   1097,
#   859,
#   1814,
#   50,
#   128,
#   294,
#   556,
#   1141,
#   38,
#   377,
#   789,
#   154,
#   402,
#   5,
#   1,
#   859,
#   10,
#   6,
#   1,
#   82,
#   859,
#   16,
#   203,
#   106,
#   15,
#   3,
#   1274,
#   30,
#   1199,
#   13,
#   226,
#   13,
#   1,
#   774,
#   1141,
#   136,
#   6,
#   15,
#   3,
#   13,
#   640,
#   17,
#   175,
#   415,
#   659,
#   88,
#   153,
#   41,
#   477,
#   659,
#   11,
#   511,
#   1141,
#   24,
#   1,
#   4,
#   59,
#   1530,
#   278,
#   337,
#   2,
#   130,
#   1141,
#   93,
#   180,
#   641,
#   859,
#   16,
#   7,
#   972,
#   3,
#   769,
#   510,
#   859,
#   113,
#   591,
#   859,
#   4,
#   260],
#  [1,
#   17,
#   53,
#   1202,
#   587,
#   1638,
#   6,
#   31,
#   26,
#   6,
#   51,
#   51,
#   48,
#   29,
#   47,
#   26,
#   123,
#   17,
#   236,
#   393,
#   150,
#   2,
#   1451,
#   6,
#   62,
#   48,
#   13,
#   1,
#   726,
#   2,
#   966,
#   128,
#   146,
#   50,
#   1,
#   61,
#   1,
#   16,
#   283,
#   130,
#   103,
#   80,
#   7,
#   64,
#   452,
#   91,
#   27,
#   310,
#   32,
#   22,
#   256,
#   7,
#   3,
#   1445,
#   2,
#   32,
#   890,
#   5,
#   735,
#   91,
#   28,
#   4,
#   3,
#   21,
#   165,
#   130,
#   103,
#   80,
#   393,
#   1306,
#   291,
#   311,
#   3,
#   197,
#   4,
#   684,
#   1,
#   61,
#   6,
#   317,
#   1,
#   112,
#   6,
#   346,
#   2,
#   1,
#   481,
#   6,
#   638,
#   9,
#   111,
#   193,
#   11,
#   58,
#   25,
#   10,
#   158,
#   17,
#   26,
#   62,
#   6,
#   2,
#   9,
#   211,
#   131,
#   10,
#   16,
#   6,
#   3,
#   211,
#   63],
#  [10,
#   6,
#   27,
#   4,
#   144,
#   592,
#   1807,
#   11,
#   44,
#   21,
#   695,
#   8,
#   1518,
#   17,
#   214,
#   1664,
#   47,
#   162,
#   10,
#   56,
#   49,
#   860,
#   4,
#   3,
#   61,
#   70,
#   6,
#   11,
#   10,
#   214,
#   138,
#   34,
#   226,
#   241,
#   7,
#   1,
#   703,
#   10,
#   43,
#   137,
#   3,
#   1132,
#   5,
#   8,
#   11,
#   8,
#   6,
#   175,
#   8,
#   12,
#   20,
#   620,
#   1,
#   828,
#   96,
#   20,
#   24,
#   73,
#   124,
#   7,
#   137,
#   175,
#   1014,
#   152,
#   6,
#   894,
#   13,
#   1,
#   332,
#   33,
#   76,
#   78,
#   228,
#   5,
#   25,
#   791,
#   1992,
#   23,
#   573,
#   186,
#   143,
#   38,
#   20,
#   55,
#   6,
#   78,
#   8,
#   53,
#   547,
#   1,
#   4,
#   6,
#   1301,
#   13,
#   23,
#   318,
#   13,
#   69,
#   21,
#   22,
#   20,
#   248,
#   336,
#   4,
#   23,
#   722,
#   41,
#   115,
#   38,
#   274,
#   38,
#   195,
#   17,
#   11,
#   6,
#   47,
#   162,
#   10,
#   1807,
#   56,
#   49,
#   1767,
#   9,
#   63,
#   3,
#   319,
#   7,
#   1,
#   227,
#   4,
#   252,
#   30,
#   1,
#   1853,
#   37,
#   235,
#   6,
#   1301,
#   7,
#   23,
#   1755,
#   5,
#   63,
#   23,
#   442,
#   27,
#   170,
#   39,
#   85,
#   351,
#   5,
#   25,
#   56,
#   1065,
#   47,
#   26,
#   490,
#   49,
#   70,
#   23,
#   1508,
#   9,
#   156,
#   100,
#   10,
#   58,
#   25,
#   3,
#   48,
#   322,
#   50,
#   8,
#   12,
#   17,
#   35,
#   1,
#   1807,
#   580,
#   9,
#   240,
#   5,
#   63,
#   85,
#   71,
#   184,
#   5,
#   1,
#   861,
#   61,
#   41,
#   83,
#   5,
#   63,
#   13,
#   3,
#   504,
#   454,
#   108,
#   30,
#   1,
#   271,
#   4,
#   1854,
#   5,
#   109,
#   29,
#   10,
#   861,
#   9,
#   39,
#   436,
#   11,
#   32,
#   66,
#   397,
#   52,
#   1,
#   533,
#   34,
#   71,
#   66,
#   819,
#   42,
#   56,
#   49,
#   85,
#   32,
#   184,
#   1,
#   1,
#   10,
#   6,
#   31,
#   216,
#   399,
#   1807,
#   9,
#   436,
#   32,
#   66,
#   397,
#   52,
#   1,
#   772,
#   56,
#   1,
#   1109,
#   297,
#   22,
#   124,
#   70,
#   87,
#   4,
#   1,
#   1241,
#   21,
#   63,
#   19,
#   1,
#   190,
#   264,
#   44,
#   21,
#   768,
#   1834,
#   79,
#   218,
#   349,
#   10,
#   636,
#   21,
#   409,
#   3,
#   333,
#   76,
#   177,
#   5,
#   63,
#   85,
#   1,
#   61,
#   381,
#   5,
#   25],
#  [10,
#   422,
#   24,
#   73,
#   124,
#   1,
#   562,
#   19,
#   1951,
#   422,
#   24,
#   73,
#   995,
#   7,
#   97,
#   81,
#   92,
#   826,
#   1539,
#   1,
#   114,
#   235,
#   4,
#   23,
#   607,
#   181,
#   31,
#   915,
#   392,
#   1,
#   105,
#   14,
#   1,
#   61,
#   2,
#   718,
#   405,
#   27,
#   4,
#   23,
#   114,
#   105,
#   350,
#   7,
#   3,
#   192,
#   54,
#   10,
#   18,
#   6,
#   444,
#   19,
#   3,
#   663,
#   30,
#   2,
#   742,
#   10,
#   6,
#   3,
#   332,
#   488,
#   61,
#   59,
#   688,
#   1,
#   103,
#   14,
#   1,
#   551,
#   1951,
#   65,
#   53,
#   332,
#   13,
#   3,
#   504,
#   34,
#   304,
#   558,
#   86,
#   7,
#   258,
#   3,
#   128,
#   439,
#   571,
#   305,
#   7,
#   818,
#   1614,
#   1,
#   4,
#   12,
#   60,
#   5,
#   25,
#   1531,
#   121,
#   7,
#   1231,
#   305,
#   7,
#   1,
#   966,
#   146,
#   43,
#   3,
#   318,
#   2,
#   103,
#   472,
#   2,
#   6,
#   265,
#   5,
#   397,
#   23,
#   472,
#   17,
#   29,
#   1,
#   168,
#   54,
#   985,
#   141,
#   23,
#   1406,
#   1,
#   684,
#   5,
#   789,
#   76,
#   2,
#   23,
#   1946,
#   15,
#   3,
#   83,
#   1252,
#   30,
#   623,
#   528,
#   1,
#   411,
#   262,
#   42,
#   17,
#   242,
#   51,
#   1,
#   61,
#   7,
#   3,
#   303,
#   953,
#   526,
#   494,
#   459,
#   30,
#   742,
#   15,
#   3,
#   460,
#   19,
#   1,
#   1558,
#   1949,
#   1,
#   61,
#   6,
#   385,
#   599,
#   7,
#   60,
#   50,
#   1664,
#   17,
#   1,
#   87,
#   670,
#   1754,
#   1421,
#   7,
#   1,
#   18,
#   6,
#   303,
#   1375,
#   10,
#   6,
#   45,
#   4,
#   1,
#   114,
#   625,
#   203,
#   106,
#   2,
#   9,
#   102,
#   3,
#   172,
#   4,
#   104,
#   1,
#   132,
#   50,
#   1951,
#   2,
#   484,
#   22,
#   7,
#   1,
#   515,
#   6,
#   175,
#   1154,
#   1,
#   320,
#   513,
#   29,
#   1,
#   1004,
#   4,
#   1,
#   515,
#   1951,
#   139,
#   1,
#   8,
#   183,
#   5,
#   1,
#   495,
#   4,
#   1,
#   515,
#   5,
#   63,
#   484,
#   2,
#   42,
#   23,
#   495,
#   13,
#   8,
#   1993,
#   8,
#   2,
#   141,
#   336,
#   183,
#   1,
#   515,
#   2,
#   3,
#   1487,
#   15,
#   3,
#   83,
#   173,
#   2,
#   1047,
#   1,
#   128,
#   3,
#   476,
#   18,
#   142,
#   660,
#   40,
#   1279,
#   33,
#   89,
#   23,
#   785,
#   18,
#   7,
#   15,
#   295,
#   930,
#   1195,
#   86,
#   994,
#   154,
#   295,
#   930,
#   948,
#   13,
#   3,
#   293,
#   163,
#   14,
#   1,
#   696,
#   747,
#   17,
#   867,
#   11,
#   26,
#   469,
#   5,
#   843,
#   19,
#   657,
#   11,
#   46,
#   12,
#   159,
#   157,
#   14,
#   86,
#   7,
#   747,
#   15,
#   60,
#   103,
#   104,
#   1279,
#   43,
#   305,
#   7,
#   57,
#   270,
#   13,
#   27,
#   4,
#   1,
#   83,
#   903,
#   7,
#   3,
#   1025,
#   4,
#   40,
#   1780,
#   672,
#   1,
#   18,
#   3,
#   509,
#   11,
#   43,
#   90,
#   1928,
#   2,
#   2,
#   1,
#   278,
#   752,
#   1,
#   1375,
#   112,
#   2,
#   61,
#   6,
#   142,
#   127,
#   1061,
#   14,
#   4,
#   157,
#   778,
#   17,
#   14,
#   146,
#   142,
#   1310,
#   7,
#   657,
#   11,
#   10,
#   6,
#   1,
#   114,
#   18,
#   4,
#   1,
#   287,
#   1065,
#   41,
#   1580,
#   3,
#   562],
#  [9,
#   12,
#   238,
#   27,
#   4,
#   1,
#   167,
#   20,
#   145,
#   1,
#   50,
#   10,
#   197,
#   9,
#   24,
#   5,
#   131,
#   50,
#   1017,
#   82,
#   1475,
#   9,
#   147,
#   11,
#   6,
#   27,
#   280,
#   17,
#   13,
#   1,
#   197,
#   26,
#   176,
#   23,
#   235,
#   2,
#   9,
#   480,
#   442,
#   86,
#   26,
#   12,
#   137,
#   3,
#   229,
#   17,
#   26,
#   118,
#   93,
#   68,
#   456,
#   9,
#   292,
#   1,
#   119,
#   5,
#   63,
#   477,
#   2,
#   1,
#   364,
#   2,
#   826,
#   192,
#   103,
#   952,
#   8,
#   12,
#   217,
#   5,
#   63,
#   293,
#   3,
#   323,
#   1852,
#   128,
#   2,
#   56,
#   49,
#   217,
#   5,
#   102,
#   826,
#   611,
#   235,
#   12,
#   3,
#   961,
#   1461,
#   2,
#   62,
#   526,
#   26,
#   1,
#   119,
#   1587,
#   12,
#   48,
#   77,
#   7,
#   3,
#   388,
#   213,
#   2,
#   1,
#   968,
#   519,
#   272,
#   7,
#   31,
#   438,
#   235,
#   470,
#   382,
#   10,
#   44,
#   21,
#   353,
#   533,
#   15,
#   3,
#   1006,
#   2,
#   145,
#   826,
#   192,
#   1131,
#   183,
#   15,
#   53,
#   19],
#  [57,
#   708,
#   36,
#   3,
#   172,
#   10,
#   16,
#   1654,
#   5,
#   637,
#   16,
#   39,
#   202,
#   2,
#   314,
#   2,
#   159,
#   157,
#   40,
#   1007,
#   1412,
#   938,
#   5,
#   138,
#   11,
#   637,
#   148,
#   1773,
#   1623,
#   5,
#   100,
#   69,
#   8,
#   58,
#   20,
#   3,
#   190,
#   862,
#   3,
#   247,
#   402,
#   1891,
#   59,
#   22,
#   983,
#   15,
#   643,
#   4,
#   402,
#   15,
#   28,
#   47,
#   589,
#   19,
#   10,
#   1218,
#   2,
#   5,
#   63,
#   85,
#   80,
#   22,
#   34,
#   5,
#   28,
#   10,
#   239,
#   4,
#   703,
#   6,
#   610,
#   248,
#   10,
#   16,
#   189,
#   45,
#   554,
#   17,
#   1,
#   322,
#   491,
#   1,
#   16,
#   6,
#   774,
#   170,
#   1022,
#   29,
#   81,
#   7,
#   1,
#   604,
#   69,
#   3,
#   1991,
#   637,
#   32,
#   22,
#   244,
#   2,
#   36,
#   631,
#   119,
#   244,
#   6,
#   3,
#   48,
#   1223,
#   41,
#   5,
#   63,
#   11,
#   1655,
#   4,
#   402,
#   24,
#   20,
#   36,
#   233,
#   483,
#   28,
#   566,
#   44,
#   21,
#   36,
#   631,
#   119,
#   10,
#   16,
#   6,
#   20,
#   14,
#   21,
#   44,
#   21,
#   261,
#   28,
#   168,
#   95,
#   44,
#   21,
#   88,
#   36,
#   938,
#   621,
#   884,
#   40,
#   146,
#   2,
#   703,
#   69,
#   111,
#   164,
#   10,
#   16],
#  [587,
#   1339,
#   379,
#   7,
#   3,
#   352,
#   1005,
#   780,
#   4,
#   1057,
#   59,
#   7,
#   15,
#   1,
#   1946,
#   4,
#   1,
#   104,
#   81,
#   319,
#   1,
#   1339,
#   6,
#   8,
#   267,
#   205,
#   657,
#   317,
#   45,
#   1037,
#   250,
#   5,
#   23,
#   640,
#   141,
#   1,
#   61,
#   1156,
#   1,
#   1946,
#   4,
#   3,
#   2,
#   90,
#   99,
#   108,
#   1195,
#   7,
#   3,
#   30,
#   259,
#   627,
#   2,
#   30,
#   1,
#   128,
#   26,
#   6,
#   71,
#   906,
#   3,
#   4,
#   1053,
#   1392,
#   2,
#   1974,
#   13,
#   71,
#   789,
#   1,
#   139,
#   1392,
#   1974,
#   520,
#   1,
#   692,
#   173,
#   22,
#   28,
#   1151,
#   15,
#   42,
#   13,
#   1801,
#   1,
#   408,
#   15,
#   31,
#   77,
#   13,
#   3,
#   849,
#   3,
#   51,
#   398,
#   1263,
#   35,
#   737,
#   13,
#   31,
#   1392,
#   1,
#   126,
#   6,
#   3,
#   352,
#   3,
#   981,
#   29,
#   192,
#   7,
#   2,
#   183,
#   3,
#   1393,
#   7,
#   45,
#   48,
#   150,
#   1005,
#   202,
#   1855,
#   2,
#   8,
#   162,
#   14,
#   3,
#   1005,
#   1147,
#   708,
#   160],
#  [10,
#   16,
#   156,
#   62,
#   862,
#   68,
#   13,
#   137,
#   8,
#   39,
#   184,
#   124,
#   2,
#   124,
#   9,
#   193,
#   718,
#   1038,
#   10,
#   69,
#   63,
#   85,
#   26,
#   123,
#   91,
#   9,
#   215,
#   822,
#   12,
#   7,
#   8,
#   9,
#   1142,
#   56,
#   147,
#   9,
#   12,
#   111,
#   3,
#   190,
#   333,
#   4,
#   1,
#   119,
#   203,
#   206,
#   419,
#   145,
#   822,
#   1,
#   350,
#   4,
#   822,
#   2,
#   718,
#   67,
#   34,
#   1244,
#   11,
#   9,
#   416,
#   36,
#   3,
#   19,
#   1,
#   1509,
#   32,
#   252,
#   121,
#   4,
#   253,
#   81,
#   34,
#   69,
#   11,
#   9,
#   416,
#   15,
#   2,
#   9,
#   1866,
#   56,
#   73,
#   10,
#   16,
#   12,
#   34,
#   69,
#   220,
#   11,
#   9,
#   469,
#   5,
#   74,
#   204,
#   19,
#   1,
#   1694,
#   5,
#   718,
#   2,
#   383,
#   86,
#   120,
#   85,
#   72,
#   9,
#   506,
#   8,
#   17,
#   9,
#   422,
#   165,
#   23,
#   608,
#   211,
#   25,
#   38,
#   138,
#   10,
#   12,
#   27,
#   4,
#   144,
#   98,
#   11,
#   9,
#   65,
#   53,
#   322,
#   47,
#   8,
#   12,
#   166,
#   5,
#   25,
#   40,
#   38,
#   33,
#   12,
#   7,
#   8,
#   38,
#   228,
#   8,
#   39,
#   381,
#   19,
#   2,
#   9,
#   193,
#   134,
#   20,
#   900,
#   63,
#   44,
#   9,
#   88,
#   36,
#   8,
#   9,
#   88,
#   24,
#   5,
#   102,
#   8,
#   2,
#   9,
#   1050,
#   52,
#   39,
#   1707,
#   8],
#  [27,
#   4,
#   1,
#   87,
#   2,
#   1762,
#   104,
#   203,
#   122,
#   106,
#   17,
#   77,
#   27,
#   4,
#   1,
#   87,
#   1572,
#   2,
#   723,
#   661,
#   10,
#   6,
#   31,
#   202,
#   36,
#   1,
#   178,
#   43,
#   111,
#   106,
#   8,
#   154,
#   514,
#   1,
#   110,
#   184,
#   68,
#   487,
#   5,
#   1668,
#   133,
#   7,
#   1,
#   372,
#   557,
#   1617,
#   36,
#   3,
#   5,
#   1,
#   235,
#   30,
#   1,
#   61,
#   4,
#   3,
#   998,
#   2,
#   3,
#   451,
#   253,
#   81,
#   176,
#   133,
#   223,
#   30,
#   223,
#   64,
#   1941,
#   6,
#   3,
#   562,
#   27,
#   1882,
#   51,
#   113,
#   802,
#   7,
#   4,
#   2,
#   366,
#   153,
#   904,
#   904,
#   6,
#   1046,
#   205,
#   1],
#  [10,
#   6,
#   31,
#   317,
#   18,
#   14,
#   666,
#   643,
#   666,
#   202,
#   447,
#   9,
#   100,
#   11,
#   1859,
#   118,
#   3,
#   83,
#   288,
#   7,
#   10,
#   18,
#   197,
#   237,
#   339,
#   467,
#   2,
#   5,
#   25,
#   3,
#   83,
#   55,
#   43,
#   3,
#   51,
#   1263,
#   2,
#   3,
#   76,
#   4,
#   5,
#   1,
#   971,
#   237,
#   147,
#   20,
#   3,
#   18,
#   4,
#   83,
#   1104,
#   2,
#   112,
#   1950,
#   20,
#   1,
#   114,
#   5,
#   24,
#   1832,
#   7,
#   57,
#   109,
#   1,
#   16,
#   406,
#   12,
#   138,
#   1185,
#   3,
#   1524,
#   14,
#   447,
#   4,
#   666,
#   643,
#   202,
#   69,
#   45,
#   527,
#   4,
#   237,
#   24,
#   73,
#   30,
#   81,
#   800,
#   916,
#   921,
#   104,
#   137,
#   13,
#   38,
#   17,
#   194,
#   20,
#   1,
#   209,
#   1,
#   209,
#   6,
#   11,
#   3,
#   7,
#   11,
#   18,
#   3,
#   51,
#   1014,
#   643,
#   33,
#   272,
#   28,
#   4,
#   37,
#   1700,
#   2,
#   643,
#   671,
#   5,
#   119,
#   174,
#   1,
#   114,
#   55,
#   66,
#   78,
#   9,
#   62,
#   506,
#   11,
#   18,
#   2,
#   292,
#   15,
#   1,
#   168,
#   339,
#   3,
#   243,
#   354,
#   751,
#   2,
#   467,
#   3,
#   72,
#   49,
#   217,
#   751,
#   70,
#   339,
#   47,
#   3,
#   8,
#   1476,
#   614,
#   242,
#   19,
#   284],
#  [10,
#   6,
#   3,
#   83,
#   16,
#   11,
#   9,
#   88,
#   100,
#   210,
#   191,
#   1105,
#   13,
#   310,
#   38,
#   7,
#   304,
#   607,
#   26,
#   294,
#   3,
#   128,
#   33,
#   6,
#   7,
#   115,
#   15,
#   3,
#   246,
#   17,
#   6,
#   95,
#   5,
#   969,
#   23,
#   1413,
#   5,
#   37,
#   300,
#   26,
#   490,
#   5,
#   7,
#   84,
#   26,
#   1286,
#   8,
#   76,
#   119,
#   23,
#   56,
#   147,
#   8,
#   12,
#   89,
#   7,
#   8,
#   6,
#   127,
#   637,
#   1,
#   83,
#   700,
#   224,
#   809,
#   6,
#   1301,
#   160,
#   160],
#  [27,
#   4,
#   1,
#   114,
#   115,
#   533,
#   9,
#   24,
#   122,
#   106,
#   8,
#   6,
#   3,
#   223,
#   36,
#   145,
#   3,
#   1368,
#   7,
#   546,
#   1266,
#   17,
#   1328,
#   190,
#   2,
#   113,
#   302,
#   3,
#   223,
#   36,
#   219,
#   1062,
#   99,
#   145,
#   10,
#   16,
#   2,
#   22,
#   41,
#   3,
#   303,
#   247,
#   146,
#   76,
#   21,
#   39,
#   52,
#   1,
#   632,
#   1814,
#   4,
#   113,
#   60,
#   11,
#   1,
#   16,
#   76,
#   408,
#   19,
#   1435,
#   2,
#   34,
#   76,
#   190,
#   1,
#   178,
#   800,
#   1945,
#   2,
#   113,
#   1,
#   178,
#   800],
#  [1211,
#   140,
#   25,
#   344,
#   5,
#   1,
#   1980,
#   284,
#   11,
#   9,
#   60,
#   1531,
#   174,
#   301,
#   467,
#   2,
#   9,
#   96,
#   24,
#   137,
#   3,
#   1234,
#   1902,
#   85,
#   1137,
#   7,
#   259,
#   678,
#   500,
#   37,
#   103,
#   472,
#   2,
#   1846,
#   5,
#   1309,
#   99,
#   2,
#   5,
#   55,
#   490,
#   37,
#   1057,
#   220,
#   17,
#   29,
#   1,
#   126,
#   55,
#   77,
#   1,
#   168,
#   818,
#   4,
#   55,
#   65,
#   380,
#   15,
#   1846,
#   7,
#   10,
#   388,
#   361,
#   15,
#   1,
#   707,
#   7,
#   678,
#   1340,
#   15,
#   3,
#   634,
#   477,
#   85,
#   66,
#   27,
#   1688,
#   1340,
#   611,
#   7,
#   10,
#   698,
#   1646,
#   54,
#   117,
#   80,
#   22,
#   146,
#   4,
#   1929,
#   7,
#   1740,
#   1747,
#   2,
#   1639,
#   14,
#   95,
#   308,
#   3,
#   1859,
#   11,
#   87,
#   80,
#   58,
#   5,
#   5,
#   1846,
#   276,
#   17,
#   26,
#   1577,
#   14,
#   99,
#   11,
#   1307,
#   59,
#   913,
#   86,
#   5,
#   581,
#   72,
#   87,
#   792,
#   199,
#   230,
#   649,
#   40,
#   1,
#   273,
#   84,
#   2,
#   1846,
#   212,
#   291,
#   69,
#   10,
#   140,
#   25,
#   1,
#   829,
#   5,
#   1,
#   507,
#   4,
#   64,
#   186,
#   9,
#   177,
#   3,
#   751,
#   9,
#   177,
#   5,
#   63,
#   85,
#   1,
#   683,
#   58,
#   99,
#   10,
#   377,
#   32,
#   199,
#   141,
#   85,
#   66,
#   27,
#   25,
#   34,
#   248,
#   40,
#   1,
#   115,
#   645,
#   48,
#   112,
#   2,
#   48,
#   1379,
#   1,
#   103,
#   113,
#   504,
#   152,
#   140,
#   20,
#   25,
#   257,
#   1,
#   426,
#   50,
#   26,
#   29,
#   1,
#   4,
#   1,
#   1452,
#   7,
#   2,
#   4,
#   260,
#   85,
#   66,
#   71,
#   855,
#   1,
#   1379,
#   4,
#   1,
#   539],
#  [2,
#   10,
#   303,
#   18,
#   6,
#   1,
#   146,
#   205,
#   1214,
#   546,
#   7,
#   1060,
#   1852,
#   7,
#   1305,
#   8,
#   405,
#   48,
#   4,
#   1,
#   4,
#   699,
#   11,
#   199,
#   69,
#   25,
#   4,
#   31,
#   46,
#   6,
#   53,
#   821,
#   7,
#   57,
#   326,
#   1,
#   872,
#   6,
#   2,
#   71,
#   22,
#   1,
#   1,
#   51,
#   4,
#   1941,
#   11,
#   2,
#   43,
#   675,
#   174,
#   79,
#   138,
#   36,
#   19,
#   90,
#   92,
#   5,
#   1,
#   2,
#   781,
#   15,
#   8,
#   6,
#   175,
#   31,
#   823,
#   581,
#   29,
#   218,
#   636,
#   111,
#   57,
#   2,
#   1,
#   168,
#   92,
#   170],
#  [9,
#   24,
#   5,
#   131,
#   11,
#   10,
#   12,
#   1,
#   114,
#   4,
#   1,
#   663,
#   1010,
#   195,
#   2,
#   22,
#   51,
#   860,
#   13,
#   2,
#   1010,
#   203,
#   106,
#   81,
#   17,
#   595,
#   1654,
#   5,
#   10,
#   27,
#   1,
#   114,
#   27,
#   14,
#   68,
#   9,
#   96,
#   111,
#   833,
#   255,
#   331,
#   392,
#   130,
#   101,
#   122,
#   170,
#   1,
#   232,
#   54,
#   9,
#   215,
#   10,
#   27,
#   12,
#   7,
#   50,
#   9,
#   12,
#   60,
#   29,
#   11,
#   54,
#   9,
#   12,
#   3,
#   2,
#   9,
#   65,
#   39,
#   328,
#   663,
#   9,
#   12,
#   336,
#   30,
#   10,
#   2,
#   9,
#   373,
#   20,
#   1009,
#   97,
#   4,
#   1,
#   668,
#   470,
#   36,
#   5,
#   63,
#   8,
#   170,
#   84,
#   41,
#   34,
#   48],
#  [29,
#   82,
#   8,
#   58,
#   302,
#   1244,
#   5,
#   1654,
#   117,
#   1,
#   624,
#   15,
#   195,
#   24,
#   195,
#   67,
#   522,
#   30,
#   2,
#   195,
#   319,
#   2,
#   1919,
#   17,
#   194,
#   117,
#   87,
#   4,
#   1,
#   126,
#   15,
#   80,
#   15,
#   811,
#   33,
#   39,
#   589,
#   5,
#   165,
#   529,
#   1845,
#   52,
#   7,
#   3,
#   584,
#   117,
#   1,
#   624,
#   6,
#   266,
#   7,
#   3,
#   336,
#   271,
#   130,
#   22,
#   80,
#   15,
#   1196,
#   103,
#   5,
#   291,
#   33,
#   22,
#   49,
#   5,
#   315,
#   1,
#   4,
#   922,
#   70,
#   166,
#   5,
#   117,
#   1,
#   624,
#   6,
#   3,
#   18,
#   1058,
#   15,
#   1678,
#   80,
#   33,
#   64,
#   707,
#   15,
#   64,
#   38,
#   45,
#   81,
#   388,
#   54,
#   22,
#   3,
#   3,
#   2,
#   1784,
#   1555,
#   42,
#   4,
#   1,
#   393,
#   1056,
#   52,
#   7,
#   3,
#   584,
#   182,
#   13,
#   1244,
#   13,
#   133,
#   9,
#   768,
#   106,
#   23,
#   432,
#   643,
#   4,
#   153,
#   444,
#   19,
#   47,
#   9,
#   24,
#   106,
#   405,
#   27,
#   4,
#   23,
#   114,
#   350,
#   13,
#   1,
#   1555,
#   176,
#   998,
#   947,
#   236,
#   1,
#   239,
#   4,
#   998,
#   33,
#   6,
#   338,
#   5,
#   52,
#   1,
#   715,
#   44,
#   8,
#   210,
#   86,
#   1613,
#   38,
#   3,
#   27,
#   310,
#   26,
#   267,
#   95,
#   226,
#   2,
#   1093,
#   3,
#   128,
#   26,
#   123,
#   23,
#   114,
#   5,
#   1107,
#   8,
#   52,
#   17,
#   179,
#   74,
#   50,
#   26,
#   730,
#   14,
#   1,
#   347,
#   1597,
#   318,
#   1837,
#   622,
#   332,
#   455,
#   1776,
#   608,
#   27,
#   7,
#   1,
#   584,
#   417,
#   13,
#   332,
#   811,
#   1,
#   178,
#   5,
#   37,
#   184,
#   5,
#   78,
#   47,
#   26,
#   66,
#   5,
#   783,
#   1,
#   150,
#   128,
#   205,
#   305,
#   117,
#   1,
#   624,
#   6,
#   1337,
#   1362,
#   1,
#   1301,
#   235,
#   35,
#   1,
#   16,
#   939,
#   1,
#   206,
#   1902,
#   55,
#   43,
#   3,
#   486,
#   11,
#   66,
#   93,
#   56,
#   1,
#   4,
#   384,
#   302,
#   1,
#   356,
#   4,
#   1,
#   173,
#   6,
#   39,
#   13,
#   1151,
#   15,
#   826,
#   13,
#   1,
#   332,
#   108,
#   3,
#   143,
#   720,
#   1,
#   112,
#   1,
#   459,
#   725,
#   1519,
#   2,
#   625,
#   22,
#   28,
#   346,
#   443,
#   41,
#   31,
#   69,
#   89,
#   18,
#   44,
#   9,
#   24,
#   27,
#   2,
#   41,
#   3,
#   51,
#   51,
#   1398,
#   41,
#   11,
#   6,
#   216,
#   95,
#   399,
#   14,
#   1,
#   213,
#   2,
#   37,
#   41,
#   3,
#   113,
#   874,
#   5,
#   261,
#   11,
#   3,
#   251,
#   36,
#   11,
#   96,
#   165,
#   759,
#   1845,
#   52,
#   15,
#   45,
#   4,
#   130,
#   101,
#   41,
#   20,
#   62,
#   37,
#   41,
#   39,
#   1,
#   92,
#   262,
#   633,
#   55,
#   182,
#   3,
#   113,
#   95,
#   303,
#   2,
#   14,
#   1,
#   169,
#   17,
#   37,
#   239,
#   872,
#   757,
#   3,
#   277,
#   4,
#   883,
#   1878,
#   5,
#   37,
#   1140],
#  [1656,
#   4,
#   1656,
#   4,
#   6,
#   3,
#   69,
#   1234,
#   35,
#   1116,
#   163,
#   325,
#   2,
#   424,
#   625,
#   894,
#   970,
#   1013,
#   1792,
#   2,
#   3,
#   862,
#   147,
#   480,
#   273,
#   266,
#   10,
#   27,
#   967,
#   60,
#   1,
#   104,
#   514,
#   224,
#   2,
#   1,
#   243,
#   115,
#   29,
#   82,
#   196,
#   2,
#   1604,
#   31,
#   896,
#   1234,
#   438,
#   16,
#   133,
#   1822,
#   7,
#   3,
#   980,
#   27,
#   4,
#   23,
#   533,
#   5,
#   1578,
#   1,
#   83,
#   560,
#   1604,
#   3,
#   181,
#   1629,
#   31,
#   15,
#   311,
#   1,
#   260,
#   4,
#   1,
#   11,
#   28,
#   4,
#   23,
#   533,
#   22,
#   278,
#   1604,
#   23,
#   40,
#   109,
#   99,
#   337,
#   1578,
#   1576,
#   5,
#   1604,
#   1240,
#   11,
#   26,
#   561,
#   10,
#   310,
#   7,
#   1656,
#   3,
#   310,
#   1041,
#   50,
#   1,
#   347,
#   1131,
#   1604,
#   561,
#   1,
#   34,
#   26,
#   23,
#   109,
#   14,
#   3,
#   160,
#   1021,
#   325,
#   804,
#   1,
#   4,
#   1656,
#   4,
#   6,
#   1013,
#   227,
#   1,
#   167,
#   384,
#   4,
#   563,
#   56,
#   49,
#   257,
#   1763,
#   35,
#   3,
#   163,
#   628,
#   15,
#   144,
#   390,
#   1116,
#   830,
#   98,
#   35,
#   1,
#   41,
#   3,
#   1,
#   60,
#   306,
#   4,
#   10,
#   18,
#   203,
#   254,
#   6,
#   908,
#   2,
#   2,
#   306,
#   56,
#   34,
#   8,
#   6,
#   69,
#   286,
#   315,
#   2,
#   42,
#   14,
#   3,
#   678,
#   1029,
#   377,
#   15,
#   38,
#   115,
#   7,
#   1,
#   213,
#   4,
#   102,
#   8,
#   2,
#   353,
#   3,
#   18,
#   11,
#   69,
#   15,
#   665,
#   1],
#  [537,
#   6,
#   27,
#   4,
#   144,
#   104,
#   11,
#   43,
#   3,
#   172,
#   5,
#   131,
#   40,
#   109,
#   7,
#   3,
#   51,
#   92,
#   9,
#   161,
#   292,
#   8,
#   133,
#   183,
#   19,
#   3,
#   1005,
#   8,
#   1367,
#   1,
#   109,
#   4,
#   31,
#   1496,
#   287,
#   150,
#   426,
#   7,
#   3,
#   388,
#   508,
#   7,
#   7,
#   2,
#   311,
#   1,
#   20,
#   72,
#   54,
#   6,
#   1081,
#   19,
#   1,
#   362,
#   1,
#   51,
#   126,
#   50,
#   1,
#   381,
#   2,
#   558,
#   1,
#   4,
#   1,
#   332,
#   1,
#   4,
#   1,
#   18,
#   6,
#   1,
#   578,
#   4,
#   554,
#   2,
#   1,
#   1516,
#   11,
#   7,
#   3,
#   388,
#   508,
#   117,
#   312,
#   690,
#   312,
#   331,
#   46,
#   22,
#   45,
#   971,
#   135,
#   11,
#   312,
#   66,
#   5,
#   3,
#   702,
#   3,
#   18,
#   15,
#   474,
#   112,
#   2,
#   936,
#   10,
#   6,
#   3,
#   18,
#   11,
#   712,
#   3,
#   61,
#   15,
#   53,
#   314,
#   297,
#   38,
#   1756,
#   38,
#   143,
#   1290,
#   8,
#   6,
#   3,
#   18,
#   40,
#   80,
#   2,
#   64,
#   452,
#   64,
#   2,
#   64,
#   3,
#   48,
#   18,
#   286,
#   145,
#   446,
#   207],
#  [18,
#   199,
#   25,
#   20,
#   34,
#   800,
#   13,
#   647,
#   339,
#   500,
#   4,
#   1,
#   38,
#   17,
#   8,
#   6,
#   431,
#   20,
#   429,
#   2,
#   514,
#   56,
#   124,
#   70,
#   130,
#   352,
#   4,
#   1,
#   509,
#   202,
#   299,
#   269,
#   7,
#   1005,
#   1103,
#   117,
#   43,
#   73,
#   553,
#   99,
#   446,
#   149,
#   4,
#   314,
#   1363,
#   1064,
#   11,
#   12,
#   553,
#   30,
#   3,
#   17,
#   27,
#   128,
#   252,
#   30,
#   1286,
#   221,
#   138,
#   49,
#   5,
#   25,
#   2,
#   34,
#   1,
#   18,
#   513,
#   10,
#   16,
#   148,
#   851,
#   15,
#   45,
#   17,
#   8,
#   1,
#   222,
#   4,
#   645,
#   196,
#   1363,
#   2,
#   922,
#   7,
#   1930,
#   178,
#   137,
#   18,
#   96,
#   25,
#   89,
#   60,
#   7,
#   1,
#   17,
#   8,
#   76,
#   111,
#   1581,
#   41,
#   41,
#   56,
#   3,
#   223,
#   85,
#   22,
#   41,
#   160,
#   42,
#   4,
#   160],
#  [118,
#   21,
#   122,
#   590,
#   85,
#   226,
#   27,
#   16,
#   96,
#   136,
#   1,
#   178,
#   4,
#   1,
#   1570,
#   15,
#   1329,
#   1329,
#   6,
#   31,
#   560,
#   451,
#   2,
#   1388,
#   33,
#   76,
#   566,
#   29,
#   159,
#   5,
#   144,
#   33,
#   754,
#   196,
#   86,
#   2,
#   30,
#   1,
#   4,
#   23,
#   1329,
#   773,
#   23,
#   876,
#   35,
#   163,
#   262,
#   1,
#   4,
#   1,
#   61,
#   122,
#   5,
#   25,
#   60,
#   81,
#   16,
#   9,
#   24,
#   106,
#   727,
#   5,
#   10,
#   58,
#   589,
#   5,
#   25,
#   1,
#   6,
#   3,
#   62,
#   360,
#   348,
#   18,
#   2,
#   76,
#   20,
#   25,
#   14,
#   312,
#   17,
#   44,
#   21,
#   22,
#   263,
#   14,
#   138,
#   1190,
#   271,
#   2,
#   91,
#   10,
#   58,
#   93,
#   3,
#   474,
#   1098,
#   78,
#   20,
#   532,
#   228,
#   36,
#   678,
#   247,
#   185,
#   137,
#   13,
#   525,
#   6],
#  [13,
#   3,
#   192,
#   333,
#   97,
#   36,
#   10,
#   76,
#   25,
#   11,
#   1208,
#   10,
#   18,
#   13,
#   3,
#   352,
#   8,
#   43,
#   41,
#   1511,
#   7,
#   81,
#   17,
#   405,
#   3,
#   4,
#   3,
#   54,
#   517,
#   11,
#   76,
#   111,
#   25,
#   46,
#   170,
#   2,
#   6,
#   1425,
#   5,
#   102,
#   19,
#   264,
#   250,
#   5,
#   93,
#   10,
#   16,
#   37,
#   201,
#   9,
#   88,
#   100,
#   55,
#   12,
#   122,
#   17,
#   8,
#   405,
#   37,
#   447,
#   3,
#   157,
#   14,
#   1,
#   54,
#   15,
#   408,
#   1113,
#   3,
#   181,
#   1472,
#   1263,
#   2,
#   45,
#   51,
#   1179,
#   112,
#   1,
#   61,
#   6,
#   17,
#   1122,
#   2,
#   1772,
#   125,
#   598,
#   465,
#   1,
#   27,
#   1957,
#   6,
#   250,
#   14,
#   87,
#   697,
#   447,
#   5,
#   864,
#   139,
#   17,
#   8,
#   5,
#   144,
#   33,
#   37,
#   671],
#  [9,
#   589,
#   5,
#   518,
#   79,
#   10,
#   16,
#   27,
#   310,
#   34,
#   9,
#   867,
#   5,
#   102,
#   8,
#   9,
#   12,
#   51,
#   15,
#   1,
#   16,
#   9,
#   193,
#   8,
#   12,
#   3,
#   385,
#   110,
#   41,
#   3,
#   83,
#   543,
#   1271,
#   3,
#   27,
#   43,
#   212,
#   141,
#   2,
# ...
#   21,
#   1532,
#   118,
#   26,
#   62,
#   122,
#   1,
#   16,
#   1156,
#   1,
#   298,
#   109,
#   4,
#   31,
#   11,
#   7,
#   948,
#   7,
#   3,
#   1734,
#   1965,
#   2,
#   91,
#   553,
#   45,
#   80,
#   31,
#   507,
#   14,
#   59,
#   26,
#   184,
#   1056,
#   2,
#   337,
#   1,
#   16,
#   513,
#   84,
#   45,
#   779,
#   184,
#   924,
#   7,
#   10,
#   105,
#   34,
#   32,
#   86,
#   5,
#   23,
#   337,
#   45,
#   49,
#   80,
#   184,
#   571,
#   2,
#   93,
#   3,
#   4,
#   1,
#   105,
#   1,
#   27,
#   71,
#   22,
#   4,
#   1,
#   16,
#   14,
#   1,
#   289,
#   169,
#   7,
#   1,
#   475,
#   71,
#   22,
#   30,
#   3,
#   546,
#   5,
#   136,
#   164,
#   1000,
#   326,
#   1419,
#   7,
#   656,
#   5,
#   134,
#   26,
#   118,
#   47,
#   26,
#   43,
#   220,
#   1,
#   670,
#   151,
#   6,
#   11,
#   1,
#   1055,
#   111,
#   405,
#   174,
#   3,
#   209,
#   4,
#   647,
#   32,
#   313,
#   1,
#   14,
#   28,
#   4,
#   174,
#   2,
#   56,
#   13,
#   71,
#   199,
#   387,
#   23,
#   1725,
#   71,
#   691,
#   111,
#   94,
#   34,
#   1,
#   82,
#   316,
#   6,
#   444,
#   721,
#   1613,
#   298,
#   179,
#   466,
#   79,
#   1543,
#   738,
#   1,
#   16,
#   137,
#   31,
#   1044,
#   157,
#   1143,
#   56,
#   1206,
#   111,
#   184,
#   812,
#   38,
#   354,
#   9,
#   88,
#   378,
#   2,
#   88,
#   177,
#   5,
#   228,
#   34,
#   1,
#   60,
#   151,
#   313,
#   5,
#   131,
#   6,
#   11,
#   44,
#   30,
#   97,
#   577,
#   21,
#   74,
#   10,
#   16,
#   746,
#   21,
#   261,
#   68,
#   1,
#   1181,
#   5,
#   63,
#   8,
#   6,
#   49,
#   70,
#   1512],
#  [3,
#   172,
#   4,
#   80,
#   825,
#   19,
#   10,
#   197,
#   17,
#   446,
#   4,
#   1,
#   22,
#   1013,
#   438,
#   7,
#   839,
#   43,
#   45,
#   62,
#   772,
#   297,
#   153,
#   20,
#   39,
#   1,
#   132,
#   17,
#   77,
#   3,
#   51,
#   817,
#   19,
#   1,
#   2,
#   3,
#   503,
#   15,
#   3,
#   22,
#   51,
#   817,
#   257,
#   14,
#   1,
#   2,
#   360,
#   348,
#   383,
#   68,
#   376,
#   29,
#   1,
#   450,
#   146,
#   14,
#   144,
#   33,
#   88,
#   120,
#   10,
#   18,
#   6,
#   31,
#   1570,
#   1786,
#   1212,
#   18,
#   11,
#   7,
#   1893,
#   7,
#   1,
#   1696,
#   41,
#   110,
#   13,
#   8,
#   1401,
#   6,
#   602,
#   3,
#   181,
#   246,
#   6,
#   1424,
#   30,
#   3,
#   167,
#   345,
#   2,
#   913,
#   5,
#   3,
#   197,
#   4,
#   1762,
#   5,
#   63,
#   117,
#   37,
#   209,
#   6,
#   10,
#   1762,
#   563,
#   28,
#   817,
#   297,
#   582,
#   1,
#   661,
#   1042,
#   7,
#   1,
#   232,
#   13,
#   69,
#   13,
#   3,
#   1346,
#   263,
#   4,
#   889,
#   5,
#   1,
#   2,
#   4,
#   7,
#   1,
#   1,
#   218,
#   1127,
#   841,
#   22,
#   29,
#   1,
#   51,
#   450,
#   4,
#   1,
#   370,
#   2,
#   4,
#   31,
#   117,
#   285,
#   345,
#   189,
#   501,
#   1,
#   604,
#   42,
#   4,
#   1,
#   246,
#   13,
#   37,
#   415,
#   730,
#   40,
#   2,
#   3,
#   329,
#   716,
#   117,
#   1,
#   285,
#   345,
#   189,
#   501,
#   1,
#   246,
#   2,
#   37,
#   5,
#   1,
#   1558,
#   130,
#   103,
#   135,
#   22,
#   536,
#   2,
#   35,
#   1,
#   1878,
#   4,
#   1,
#   356,
#   4,
#   1,
#   1,
#   519,
#   33,
#   294,
#   1,
#   1436,
#   4,
#   1,
#   6,
#   180,
#   1075,
#   29,
#   108,
#   7,
#   1455,
#   2,
#   299,
#   3,
#   48,
#   1162,
#   4,
#   2,
#   534,
#   19,
#   366,
#   37,
#   13,
#   55,
#   43,
#   5,
#   37,
#   415,
#   2,
#   1291,
#   22,
#   252,
#   14,
#   630,
#   19,
#   126,
#   22,
#   45,
#   4,
#   1,
#   81,
#   55,
#   299,
#   6,
#   108,
#   52,
#   7,
#   3,
#   35,
#   3,
#   311,
#   1,
#   60,
#   207,
#   55,
#   6,
#   344,
#   3,
#   356,
#   77,
#   46,
#   6,
#   3,
#   1190,
#   132,
#   117,
#   1,
#   139,
#   29,
#   37,
#   2,
#   27,
#   81,
#   132,
#   117,
#   55,
#   6,
#   7,
#   31,
#   1048,
#   2,
#   913,
#   5,
#   3,
#   4,
#   714,
#   55,
#   44,
#   21,
#   768,
#   106,
#   10,
#   197,
#   9,
#   436,
#   9,
#   24,
#   1670,
#   21,
#   1193,
#   722,
#   38,
#   20,
#   21,
#   177,
#   5,
#   198,
#   10,
#   386,
#   3,
#   320,
#   708,
#   462,
#   160,
#   14],
#  [1,
#   12,
#   614,
#   19,
#   370,
#   7,
#   1,
#   82,
#   370,
#   129,
#   7,
#   7,
#   27,
#   669,
#   46,
#   67,
#   244,
#   19,
#   308,
#   1401,
#   15,
#   150,
#   16,
#   747,
#   7,
#   388,
#   1,
#   46,
#   67,
#   150,
#   15,
#   2,
#   4,
#   778,
#   7,
#   3,
#   329,
#   669,
#   46,
#   67,
#   53,
#   39,
#   1054,
#   11,
#   12,
#   1,
#   669,
#   9,
#   960,
#   80,
#   184,
#   308,
#   7,
#   46,
#   11,
#   507,
#   60,
#   1282,
#   5,
#   1,
#   4,
#   1,
#   370,
#   9,
#   12,
#   3,
#   1,
#   135,
#   9,
#   419,
#   87,
#   2,
#   373,
#   5,
#   10,
#   247,
#   22,
#   1,
#   1,
#   219,
#   770,
#   1279,
#   1,
#   1309,
#   1992,
#   1125,
#   139,
#   1,
#   1411,
#   1,
#   19,
#   47,
#   12,
#   848,
#   5,
#   25,
#   1,
#   643,
#   4,
#   3,
#   251,
#   1,
#   232,
#   12,
#   51,
#   4,
#   1,
#   517,
#   1044,
#   146,
#   203,
#   412,
#   3,
#   172,
#   4,
#   11,
#   22,
#   461,
#   33,
#   6,
#   17,
#   1679,
#   68,
#   41,
#   158,
#   534,
#   27,
#   279,
#   9,
#   12,
#   3,
#   12,
#   11,
#   9,
#   2,
#   57,
#   365,
#   58,
#   717,
#   81,
#   5,
#   63,
#   8,
#   71,
#   58,
#   864,
#   2,
#   102,
#   1,
#   1584,
#   4,
#   1,
#   13,
#   1,
#   1279,
#   58,
#   293,
#   13,
#   1,
#   366,
#   1359,
#   7,
#   19,
#   1279,
#   71,
#   58,
#   853,
#   14,
#   11,
#   445,
#   4,
#   19,
#   1,
#   389,
#   253,
#   54,
#   12,
#   49,
#   638,
#   70,
#   1,
#   232,
#   2,
#   91,
#   11,
#   58,
#   91,
#   717,
#   3,
#   458,
#   5,
#   63,
#   1,
#   119,
#   47,
#   71,
#   65,
#   220,
#   5,
#   74,
#   10,
#   972,
#   21,
#   211,
#   102,
#   1,
#   370,
#   418,
#   45,
#   4,
#   8,
#   6,
#   1959,
#   17,
#   87,
#   294,
#   18,
#   693,
#   2,
#   146,
#   22,
#   39,
#   164,
#   29,
#   97,
#   370,
#   89,
#   7,
#   1,
#   9,
#   118,
#   63,
#   1,
#   7,
#   3,
#   747,
#   13,
#   3,
#   18,
#   3,
#   35,
#   1,
#   200,
#   370,
#   8,
#   65,
#   73,
#   601,
#   2,
#   12,
#   1009,
#   45,
#   4,
#   1,
#   200,
#   308,
#   209,
#   135,
#   1,
#   82,
#   310,
#   408,
#   119,
#   1882,
#   1309,
#   4,
#   194,
#   1,
#   229,
#   35,
#   1,
#   34,
#   8,
#   12,
#   3,
#   14,
#   9,
#   187,
#   164,
#   29,
#   3,
#   66,
#   4,
#   205,
#   1,
#   540,
#   116,
#   125,
#   952,
#   15,
#   3,
#   1162,
#   4,
#   770,
#   2,
#   531,
#   4,
#   1,
#   206,
#   210,
#   68,
#   1096,
#   7,
#   1,
#   734,
#   7,
#   1,
#   1126,
#   1,
#   398,
#   1691,
#   67,
#   207,
#   1,
#   12,
#   1472,
#   157,
#   2,
#   62,
#   1,
#   481,
#   4,
#   1,
#   207,
#   8,
#   3,
#   481,
#   11,
#   281,
#   1433,
#   7,
#   97,
#   81],
#  [10,
#   119,
#   43,
#   3,
#   83,
#   763,
#   41,
#   51,
#   860,
#   3,
#   318,
#   1439,
#   2,
#   26,
#   189,
#   453,
#   4,
#   23,
#   472,
#   580,
#   34,
#   26,
#   19,
#   23,
#   591,
#   7,
#   1161,
#   23,
#   114,
#   458,
#   2,
#   107,
#   404,
#   212,
#   298,
#   19,
#   7,
#   1,
#   119,
#   137,
#   13,
#   1,
#   242,
#   562,
#   904,
#   2,
#   33,
#   21,
#   66,
#   165,
#   42,
#   14,
#   621,
#   9,
#   88,
#   177,
#   5,
#   8,
#   14,
#   21,
#   2,
#   4,
#   1,
#   4,
#   17,
#   1,
#   358,
#   22,
#   385,
#   95,
#   10,
#   6,
#   1083,
#   1868,
#   2,
#   82,
#   558,
#   121,
#   2,
#   77,
#   21,
#   199,
#   120,
#   35,
#   283,
#   36,
#   2,
#   194,
#   34,
#   294,
#   1,
#   115,
#   498,
#   651,
#   504,
#   33,
#   760,
#   313,
#   42,
#   62,
#   10,
#   6,
#   3,
#   51,
#   48,
#   119],
#  [16,
#   1322,
#   909,
#   834,
#   285,
#   4,
#   1,
#   829,
#   5,
#   1,
#   264,
#   32,
#   787,
#   1,
#   87,
#   1059,
#   1120,
#   104,
#   4,
#   28,
#   54,
#   1,
#   82,
#   12,
#   23,
#   352,
#   424,
#   2,
#   1,
#   1536,
#   620,
#   7,
#   1,
#   232,
#   12,
#   1,
#   91,
#   461,
#   930,
#   59,
#   89,
#   41,
#   7,
#   7,
#   196,
#   130,
#   103,
#   12,
#   377,
#   23,
#   87,
#   1252,
#   4,
#   3,
#   352,
#   780,
#   4,
#   1,
#   285,
#   104,
#   6,
#   1,
#   27,
#   87,
#   5,
#   90,
#   1021,
#   424,
#   59,
#   14,
#   124,
#   38,
#   429,
#   873,
#   14,
#   107,
#   1,
#   306,
#   4,
#   1,
#   61,
#   118,
#   20,
#   789,
#   1,
#   168,
#   258,
#   8,
#   12,
#   3,
#   565,
#   2,
#   36,
#   424,
#   12,
#   1895,
#   14,
#   1,
#   909,
#   8,
#   111,
#   1,
#   168,
#   307,
#   59,
#   8,
#   431,
#   1809,
#   909,
#   14,
#   276,
#   118,
#   305,
#   20,
#   5,
#   15,
#   3,
#   352,
#   300,
#   2,
#   5,
#   1,
#   780,
#   243,
#   70,
#   8,
#   14,
#   1,
#   264,
#   1,
#   955,
#   12,
#   3,
#   4,
#   894,
#   744,
#   7,
#   1288,
#   1791,
#   2,
#   1,
#   399,
#   540,
#   1952,
#   834,
#   1,
#   61,
#   5,
#   109,
#   15,
#   3,
#   11,
#   5,
#   10,
#   247,
#   1411,
#   33,
#   12,
#   3,
#   1873,
#   4,
#   1,
#   686,
#   13,
#   3,
#   5,
#   1,
#   4,
#   1,
#   814,
#   1542,
#   623,
#   2,
#   1513,
#   50,
#   909,
#   552,
#   94,
#   26,
#   695,
#   26,
#   65,
#   254,
#   23,
#   2,
#   845,
#   26,
#   65,
#   1411,
#   4,
#   3,
#   920,
#   6,
#   3,
#   653,
#   125,
#   477,
#   162,
#   34,
#   10,
#   6,
#   115,
#   2,
#   445,
#   1942,
#   1043,
#   22,
#   399,
#   33,
#   58,
#   136,
#   19,
#   5,
#   540,
#   7,
#   930,
#   1989,
#   1,
#   4,
#   1,
#   133,
#   1695,
#   2,
#   67,
#   1600,
#   1168,
#   13,
#   195,
#   1,
#   705,
#   2,
#   1,
#   1756,
#   2,
#   587,
#   12,
#   13,
#   195,
#   2,
#   1017,
#   43,
#   113,
#   802,
#   13,
#   1,
#   1885,
#   703,
#   735,
#   119,
#   1951,
#   1765,
#   23,
#   1113,
#   540,
#   17,
#   18,
#   2,
#   909,
#   12,
#   1442,
#   5,
#   293,
#   1,
#   2,
#   55,
#   89,
#   1,
#   114,
#   608,
#   1,
#   729,
#   37,
#   201,
#   119,
#   787,
#   1,
#   1895,
#   14,
#   1,
#   164,
#   4,
#   1,
#   18,
#   12,
#   1083,
#   622,
#   1579,
#   357,
#   4,
#   1394,
#   12,
#   30,
#   909,
#   37,
#   779,
#   805,
#   757,
#   5,
#   1,
#   486,
#   4,
#   1,
#   16,
#   17,
#   87,
#   670,
#   4,
#   22,
#   1,
#   860,
#   101,
#   35,
#   204,
#   176,
#   5,
#   1,
#   441,
#   1129,
#   32,
#   717,
#   195,
#   109,
#   2,
#   5,
#   1,
#   396,
#   575,
#   61,
#   138,
#   51,
#   874,
#   5,
#   983,
#   7,
#   31,
#   1120,
#   18,
#   7,
#   15,
#   1,
#   592,
#   287,
#   2,
#   20,
#   34,
#   1,
#   578,
#   806,
#   43,
#   39,
#   73,
#   620,
#   19,
#   3,
#   314,
#   284,
#   8,
#   327,
#   43,
#   111,
#   605,
#   124,
#   1,
#   1310,
#   18,
#   211,
#   25,
#   106,
#   5,
#   25,
#   8,
#   5,
#   131,
#   8,
#   268,
#   385,
#   31,
#   809,
#   43,
#   73,
#   1282,
#   2,
#   1,
#   224,
#   69,
#   1,
#   284,
#   146,
#   3,
#   1272,
#   169,
#   4,
#   909,
#   22,
#   95,
#   1939,
#   5,
#   1025,
#   129,
#   17,
#   13,
#   640,
#   45,
#   22,
#   522,
#   946,
#   472,
#   45,
#   22,
#   5,
#   1467,
#   2,
#   1,
#   356,
#   803,
#   1194,
#   7,
#   196,
#   17,
#   143,
#   447,
#   76,
#   177,
#   5,
#   74,
#   1,
#   266,
#   84,
#   363,
#   15,
#   31,
#   774,
#   35,
#   1,
#   18,
#   2,
#   105,
#   8,
#   1676,
#   3,
#   1507,
#   270,
#   59,
#   20,
#   60,
#   87,
#   4,
#   1,
#   814,
#   254,
#   7,
#   1,
#   270,
#   15,
#   1,
#   314,
#   340,
#   370,
#   761,
#   17,
#   72,
#   49,
#   13,
#   69,
#   13,
#   640,
#   14,
#   909,
#   76,
#   60,
#   25,
#   1433,
#   14,
#   3,
#   1761,
#   54,
#   34,
#   44,
#   36,
#   68,
#   21,
#   22,
#   3,
#   1457,
#   74,
#   8,
#   146,
#   10,
#   6,
#   367,
#   3,
#   920,
#   212,
#   278],
#  [20,
#   1271,
#   47,
#   10,
#   18,
#   12,
#   40,
#   9,
#   8,
#   42,
#   29,
#   1,
#   370,
#   1126,
#   2,
#   99,
#   315,
#   8,
#   9,
#   506,
#   8,
#   113,
#   106,
#   509,
#   505,
#   35,
#   163,
#   83,
#   61,
#   2,
#   101,
#   13,
#   3,
#   333,
#   4,
#   9,
#   12,
#   766,
#   4,
#   37,
#   696,
#   1186,
#   1,
#   60,
#   1396,
#   14,
#   10,
#   18,
#   12,
#   1,
#   273,
#   186,
#   8,
#   6,
#   286,
#   1,
#   850],
#  [50,
#   9,
#   215,
#   1,
#   4,
#   287,
#   29,
#   82,
#   54,
#   9,
#   65,
#   53,
#   1397,
#   14,
#   11,
#   16,
#   258,
#   8,
#   281,
#   34,
#   75,
#   13,
#   9,
#   12,
#   193,
#   41,
#   239,
#   4,
#   1116,
#   306,
#   4,
#   15,
#   173,
#   11,
#   6,
#   216,
#   800,
#   7,
#   582,
#   491,
#   1,
#   61,
#   6,
#   2,
#   33,
#   22,
#   77,
#   1895,
#   14,
#   61,
#   4,
#   859,
#   21,
#   66,
#   77,
#   63,
#   81,
#   5,
#   1116,
#   185,
#   98,
#   294,
#   1,
#   213,
#   4,
#   2,
#   21,
#   66,
#   63,
#   11,
#   549,
#   7,
#   539,
#   4,
#   1,
#   576,
#   347,
#   4,
#   604,
#   13,
#   304,
#   2,
#   7,
#   13,
#   1,
#   213,
#   4,
#   591,
#   175,
#   438,
#   16,
#   15,
#   45,
#   749,
#   527],
#  [205,
#   1747,
#   10,
#   18,
#   59,
#   9,
#   58,
#   36,
#   5,
#   165,
#   7,
#   284,
#   1465,
#   31,
#   7,
#   1,
#   2,
#   1747,
#   4,
#   193,
#   4,
#   1,
#   80,
#   154,
#   1,
#   4,
#   1,
#   178,
#   11,
#   46,
#   6,
#   149,
#   3,
#   163,
#   2,
#   3,
#   560,
#   96,
#   27,
#   137,
#   2,
#   137,
#   3,
#   728,
#   878,
#   5,
#   78,
#   8,
#   4,
#   94,
#   992,
#   885,
#   68,
#   8,
#   58,
#   25,
#   1664,
#   5,
#   25,
#   498,
#   5,
#   63,
#   2,
#   791,
#   8,
#   18,
#   14,
#   124,
#   70,
#   1,
#   2,
#   174,
#   5,
#   93,
#   1581,
#   4,
#   5,
#   25,
#   1923,
#   2,
#   413,
#   5,
#   1774,
#   4,
#   137,
#   38,
#   137,
#   457,
#   4,
#   193,
#   84,
#   10,
#   193,
#   216,
#   1163,
#   5,
#   230,
#   7,
#   1,
#   178,
#   186,
#   808,
#   4,
#   259,
#   1990,
#   11,
#   60,
#   94,
#   703,
#   76,
#   25,
#   498,
#   5,
#   15,
#   44,
#   1844,
#   690,
#   117,
#   9,
#   91,
#   5,
#   74,
#   3,
#   1034,
#   38,
#   1858,
#   5,
#   68,
#   38,
#   1294,
#   21,
#   7],
#  [10,
#   16,
#   6,
#   39,
#   83,
#   41,
#   438,
#   35,
#   450,
#   5,
#   1,
#   126,
#   330,
#   206,
#   25,
#   29,
#   1,
#   1283,
#   4,
#   125,
#   465,
#   1,
#   432,
#   16,
#   7,
#   57,
#   648,
#   10,
#   16,
#   6,
#   541,
#   30,
#   1,
#   1416,
#   945,
#   79,
#   1,
#   213,
#   4,
#   1,
#   69,
#   229,
#   291,
#   15,
#   86,
#   484,
#   162,
#   3,
#   83,
#   1263,
#   13,
#   2,
#   91,
#   304,
#   27,
#   4,
#   1,
#   114,
#   350,
#   203,
#   106,
#   4,
#   86,
#   13,
#   3,
#   1015,
#   2,
#   1,
#   188,
#   11,
#   4,
#   1,
#   16,
#   299,
#   269,
#   29,
#   3,
#   15,
#   3,
#   222,
#   172,
#   4,
#   75,
#   489,
#   19,
#   8,
#   162,
#   92,
#   14,
#   3,
#   172,
#   4,
#   202,
#   526,
#   16],
#  [203,
#   106,
#   1,
#   200,
#   629,
#   306,
#   19,
#   370,
#   1098,
#   4,
#   540,
#   152,
#   268,
#   51,
#   9,
#   187,
#   261,
#   142,
#   657,
#   11,
#   1,
#   61,
#   6,
#   40,
#   3,
#   181,
#   426,
#   33,
#   888,
#   3,
#   246,
#   15,
#   3,
#   475,
#   11,
#   6,
#   15,
#   23,
#   201,
#   1,
#   103,
#   22,
#   1370,
#   79,
#   27,
#   4,
#   1,
#   87,
#   249,
#   2,
#   1767,
#   7,
#   97,
#   1120,
#   18,
#   1,
#   744,
#   486,
#   6,
#   317,
#   44,
#   870,
#   106,
#   288,
#   4,
#   21,
#   66,
#   63,
#   1,
#   486,
#   7,
#   64,
#   361,
#   8,
#   216,
#   94,
#   14,
#   1,
#   61,
#   4,
#   1,
#   424,
#   17,
#   20,
#   175,
#   413,
#   104,
#   22,
#   108,
#   620,
#   9,
#   187,
#   853,
#   5,
#   63,
#   31,
#   629,
#   306,
#   4],
#  [9,
#   12,
#   142,
#   3,
#   127,
#   928,
#   8,
#   12,
#   39,
#   155,
#   16,
#   9,
#   292,
#   19,
#   244,
#   91,
#   9,
#   65,
#   5,
#   74,
#   1,
#   370,
#   5,
#   413,
#   165,
#   42,
#   85,
#   8,
#   624,
#   91,
#   9,
#   469,
#   1,
#   284,
#   84,
#   1,
#   1172,
#   82,
#   4,
#   99,
#   3,
#   167,
#   99,
#   1,
#   284,
#   9,
#   65,
#   5,
#   57,
#   952,
#   19,
#   1,
#   809,
#   91,
#   19,
#   446,
#   18,
#   2,
#   1,
#   18,
#   225,
#   204,
#   146,
#   8,
#   43,
#   409,
#   11,
#   429,
#   11,
#   9,
#   349,
#   5,
#   81,
#   80,
#   79,
#   15,
#   57,
#   2,
#   127,
#   928,
#   85,
#   96,
#   11,
#   589,
#   47,
#   68,
#   79,
#   606,
#   41,
#   27,
#   4,
#   144,
#   158,
#   17,
#   816,
#   612,
#   2,
#   1086,
#   1287,
#   36,
#   60,
#   1,
#   696,
#   66,
#   1,
#   16,
#   6,
#   967,
#   35,
#   534,
#   36,
#   6,
#   84,
#   4,
#   1,
#   101,
#   11,
#   709,
#   38,
#   641,
#   17,
#   143,
#   10,
#   6,
#   3,
#   61,
#   40,
#   345,
#   393,
#   918,
#   95,
#   3,
#   61,
#   40,
#   345,
#   393,
#   363,
#   15,
#   253,
#   81,
#   38,
#   88,
#   8,
#   1358,
#   45,
#   4,
#   1,
#   114,
#   152,
#   610,
#   1750,
#   1659,
#   1473,
#   2,
#   984,
#   984,
#   33,
#   1453,
#   19,
#   27,
#   4,
#   1,
#   114,
#   350,
#   203,
#   122,
#   106,
#   7,
#   3,
#   18,
#   48,
#   1,
#   809,
#   6,
#   1296,
#   1526,
#   43,
#   394,
#   1,
#   686,
#   14,
#   1,
#   1135,
#   676,
#   33,
#   294,
#   128,
#   2,
#   984,
#   1,
#   17,
#   1945,
#   1533,
#   22,
#   62,
#   1113,
#   71,
#   120,
#   11,
#   40,
#   17,
#   44,
#   870,
#   60,
#   552,
#   984,
#   1113,
#   7,
#   115,
#   161,
#   21,
#   24,
#   53,
#   322,
#   85,
#   83,
#   2,
#   971,
#   23,
#   540,
#   6,
#   69,
#   485,
#   14,
#   171,
#   132,
#   5,
#   212,
#   14,
#   1,
#   1742,
#   54,
#   257,
#   144,
#   135,
#   1386,
#   781,
#   5,
#   25,
#   498,
#   5,
#   62,
#   754,
#   7,
#   1,
#   1102,
#   50,
#   676,
#   6,
#   395,
#   28,
#   116,
#   1,
#   178,
#   1113,
#   19,
#   1,
#   346,
#   4,
#   125,
#   21,
#   192,
#   5,
#   1408,
#   2,
#   15,
#   4,
#   80,
#   1,
#   4,
#   1,
#   143,
#   676,
#   29,
#   1410,
#   861,
#   41,
#   250,
#   17,
#   142,
#   5,
#   10,
#   18,
#   142,
#   5,
#   676,
#   44,
#   221,
#   3,
#   178,
#   117,
#   10,
#   1135,
#   62,
#   470,
#   36,
#   5,
#   843,
#   46,
#   184,
#   127,
#   928,
#   255],
#  [7,
#   45,
#   765,
#   1,
#   4,
#   337,
#   17,
#   8,
#   77,
#   1978,
#   45,
#   4,
#   11,
#   592,
#   1,
#   110,
#   4,
#   10,
#   27,
#   6,
#   49,
#   70,
#   1,
#   82,
#   59,
#   6,
#   175,
#   476,
#   1,
#   329,
#   316,
#   4,
#   1,
#   774,
#   6,
#   3,
#   172,
#   2,
#   3,
#   172,
#   5,
#   139,
#   362,
#   11,
#   6,
#   21,
#   74,
#   5,
#   1,
#   981,
#   135,
#   60,
#   1,
#   22,
#   124,
#   2,
#   1,
#   1,
#   4,
#   1,
#   156,
#   120,
#   3,
#   35,
#   23,
#   204,
#   1865,
#   2,
#   13,
#   3,
#   955,
#   32,
#   22,
#   49,
#   38,
#   324,
#   1,
#   168,
#   13,
#   1,
#   7,
#   14,
#   457,
#   258,
#   1,
#   691,
#   13,
#   3,
#   59,
#   6,
#   289,
#   13,
#   493,
#   5,
#   37,
#   5,
#   86,
#   50,
#   55,
#   210,
#   5,
#   1,
#   82,
#   151,
#   55,
#   123,
#   6,
#   136,
#   5,
#   1,
#   129,
#   22,
#   691,
#   502,
#   216,
#   36,
#   1,
#   4,
#   94,
#   6,
#   638,
#   257,
#   1,
#   33,
#   43,
#   103,
#   135,
#   105,
#   43,
#   73,
#   344,
#   49,
#   26,
#   6,
#   72,
#   49,
#   28,
#   26,
#   123,
#   6,
#   23,
#   1946,
#   7,
#   1,
#   200,
#   2,
#   22,
#   29,
#   1426,
#   836,
#   257,
#   29,
#   1,
#   132,
#   59,
#   6,
#   15,
#   329,
#   235,
#   5,
#   31,
#   476,
#   958,
#   186,
#   13,
#   6,
#   1,
#   872,
#   4,
#   10,
#   316,
#   4,
#   1,
#   1,
#   592,
#   476,
#   1754,
#   22,
#   1009,
#   7,
#   10,
#   27,
#   14,
#   1,
#   87,
#   169,
#   545,
#   14,
#   3,
#   716,
#   117,
#   176,
#   15,
#   1,
#   1000,
#   1,
#   27,
#   151,
#   9,
#   78,
#   24,
#   5,
#   5,
#   6,
#   1,
#   92,
#   1438,
#   1,
#   273,
#   1039,
#   7,
#   1,
#   99,
#   2,
#   32,
#   22,
#   7,
#   23,
#   2,
#   11,
#   26,
#   117,
#   26,
#   43,
#   1592,
#   1,
#   26,
#   2,
#   55,
#   759,
#   37,
#   591,
#   50,
#   127,
#   55,
#   86,
#   38,
#   865,
#   6,
#   34,
#   11,
#   3,
#   251,
#   58,
#   5,
#   584,
#   3,
#   83,
#   11,
#   26,
#   7,
#   466,
#   37,
#   37,
#   3,
#   251,
#   33,
#   6,
#   72,
#   7,
#   1,
#   70,
#   26,
#   6,
#   129,
#   555,
#   138,
#   704,
#   36,
#   68,
#   9,
#   66,
#   387,
#   134,
#   32,
#   58,
#   177,
#   5,
#   397,
#   3,
#   4,
#   54,
#   2,
#   269,
#   13,
#   956,
#   94,
#   35,
#   1,
#   1656,
#   5,
#   1,
#   1166,
#   4,
#   1,
#   103,
#   58,
#   93,
#   1,
#   18,
#   51,
#   9,
#   77,
#   387,
#   134,
#   32,
#   156,
#   24,
#   511,
#   23,
#   105,
#   6,
#   72,
#   129,
#   23,
#   400,
#   6,
#   60,
#   1042,
#   276,
#   17,
#   5,
#   24,
#   511,
#   759,
#   337,
#   35,
#   1,
#   6,
#   39,
#   5,
#   1,
#   307,
#   300,
#   4,
#   94,
#   1,
#   209,
#   4,
#   1,
#   6,
#   11,
#   267,
#   226,
#   720,
#   8,
#   140,
#   79,
#   1,
#   4,
#   1046,
#   441,
#   129,
#   71,
#   327,
#   24,
#   37,
#   781,
#   14,
#   37,
#   412,
#   115,
#   41,
#   20,
#   13,
#   217],
#  ...]

# %%
model = Sequential()
model.add(Embedding(input_dim=2000,output_dim=32,input_length=100))
model.add(Flatten())
#model.add(SimpleRNN(units=32))
model.add(Dense(units=256,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
train_his = model.fit(x_train_v,y_train,batch_size=128,epochs=10,verbose=2,validation_split=0.1)
scores = model.evaluate(x_test_v,y_test,verbose=1)
scores[1]
# Out:
# WARNING:tensorflow:From /Users/pan/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 32)           64000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               819456
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 883,713
# Trainable params: 883,713
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /Users/pan/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 22500 samples, validate on 2500 samples
# Epoch 1/10
#  - 2s - loss: 0.4772 - accuracy: 0.7525 - val_loss: 0.4447 - val_accuracy: 0.7860
# Epoch 2/10
#  - 2s - loss: 0.2517 - accuracy: 0.8991 - val_loss: 0.3867 - val_accuracy: 0.8292
# Epoch 3/10
#  - 2s - loss: 0.1174 - accuracy: 0.9639 - val_loss: 0.7278 - val_accuracy: 0.7508
# Epoch 4/10
#  - 2s - loss: 0.0326 - accuracy: 0.9930 - val_loss: 0.8308 - val_accuracy: 0.7804
# Epoch 5/10
#  - 2s - loss: 0.0065 - accuracy: 0.9996 - val_loss: 0.8645 - val_accuracy: 0.8012
# Epoch 6/10
#  - 2s - loss: 0.0020 - accuracy: 0.9999 - val_loss: 1.0033 - val_accuracy: 0.7880
# Epoch 7/10
#  - 2s - loss: 9.2074e-04 - accuracy: 1.0000 - val_loss: 1.0682 - val_accuracy: 0.7860
# Epoch 8/10
#  - 2s - loss: 6.1178e-04 - accuracy: 1.0000 - val_loss: 1.0808 - val_accuracy: 0.7896
# Epoch 9/10
#  - 2s - loss: 4.4397e-04 - accuracy: 1.0000 - val_loss: 1.1323 - val_accuracy: 0.7860
# Epoch 10/10
#  - 2s - loss: 3.3903e-04 - accuracy: 1.0000 - val_loss: 1.1659 - val_accuracy: 0.7864
# 25000/25000 [==============================] - 1s 33us/step
# 0.8224800229072571

# %%
from __future__ import print_function
import paddle
import paddle.fluid as fluid
import numpy as np
import sys
import math

# %%
CLASS_DIM = 2     
EMB_DIM = 128     
HID_DIM = 512     
STACKED_NUM = 3   
BATCH_SIZE = 128

# %%
def stacked_lstm_net(data, input_dim, class_dim, emb_dim, hid_dim, stacked_num):

    
    emb = fluid.layers.embedding(
        input=data, size=[input_dim, emb_dim], is_sparse=True)
    
    fc1 = fluid.layers.fc(input=emb, size=hid_dim)
    
    lstm1, cell1 = fluid.layers.dynamic_lstm(input=fc1, size=hid_dim)

    inputs = [fc1, lstm1]
    for i in range(2, stacked_num + 1):
        fc = fluid.layers.fc(input=inputs, size=hid_dim)
        lstm, cell = fluid.layers.dynamic_lstm(
            input=fc, size=hid_dim, is_reverse=(i % 2) == 0)
        inputs = [fc, lstm]
    
    fc_last = fluid.layers.sequence_pool(input=inputs[0], pool_type='max')
    lstm_last = fluid.layers.sequence_pool(input=inputs[1], pool_type='max')

    prediction = fluid.layers.fc(
        input=[fc_last, lstm_last], size=class_dim, act='softmax')
    return prediction

# %%
def inference_program(word_dict):
    data = fluid.layers.data(
        name="words", shape=[1], dtype="int64", lod_level=1)

    dict_dim = len(word_dict)
    #net = convolution_net(data, dict_dim, CLASS_DIM, EMB_DIM, HID_DIM)
    net = stacked_lstm_net(data, dict_dim, CLASS_DIM, EMB_DIM, HID_DIM, STACKED_NUM)
    return net

# %%
def train_program(prediction):
    label = fluid.layers.data(name="label", shape=[1], dtype="int64")
    cost = fluid.layers.cross_entropy(input=prediction, label=label)
    avg_cost = fluid.layers.mean(cost)
    accuracy = fluid.layers.accuracy(input=prediction, label=label)
    return [avg_cost, accuracy]

# %%
def optimizer_func():
    return fluid.optimizer.Adagrad(learning_rate=0.002)

# %%
use_cuda = False  
place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()

# %%
print("Loading IMDB word dict....")
word_dict = paddle.dataset.imdb.word_dict()
# Out:
# Loading IMDB word dict....

# %%
print ("Reading training data....")
train_reader = paddle.batch(
    paddle.reader.shuffle(
        paddle.dataset.imdb.train(word_dict), buf_size=25000),
    batch_size=BATCH_SIZE)
# Out:
# Reading training data....

# %%
print("Reading testing data....")
test_reader = paddle.batch(
    paddle.dataset.imdb.test(word_dict), batch_size=BATCH_SIZE)
# Out:
# Reading testing data....

# %%
exe = fluid.Executor(place)
prediction = inference_program(word_dict)
[avg_cost, accuracy] = train_program(prediction)
sgd_optimizer = optimizer_func()
sgd_optimizer.minimize(avg_cost)
# Out:
# ([inputs {
#     parameter: "Grad"
#     arguments: "embedding_0.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "embedding_0.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "embedding_0.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "embedding_0.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "embedding_0.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "embedding_0.w_0"
#     strings: "embedding_0.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_0.b_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_0.b_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_0.b_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_0.b_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_0.b_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_0.b_0"
#     strings: "fc_0.b_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_1/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_0.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_0.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_0.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_0.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_0.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_0.w_0"
#     strings: "fc_0.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_2/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_1.b_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_1.b_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_1.b_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_1.b_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_1.b_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_1.b_0"
#     strings: "fc_1.b_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_3/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_1.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_1.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_1.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_1.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_1.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_1.w_0"
#     strings: "fc_1.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_4/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_1.w_1@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_1.w_1_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_1.w_1"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_1.w_1_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_1.w_1"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_1.w_1"
#     strings: "fc_1.w_1@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_5/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_2.b_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_2.b_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_2.b_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_2.b_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_2.b_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_2.b_0"
#     strings: "fc_2.b_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_6/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_2.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_2.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_2.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_2.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_2.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_2.w_0"
#     strings: "fc_2.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
# ...
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_16/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "lstm_2.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "lstm_2.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "lstm_2.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "lstm_2.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "lstm_2.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "lstm_2.w_0"
#     strings: "lstm_2.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/framework.py\", line 2459, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 1372, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 433, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 590, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 620, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/optimizer.py\", line 685, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/dygraph/base.py\", line 78, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"<decorator-gen-160>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-23-d1dcc441f2d4>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3267, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3191, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 3020, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2845, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py\", line 2819, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 534, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 267, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 326, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py\", line 357, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1147, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/gen.py\", line 1233, in inner\n    self.run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/stack_context.py\", line 300, in null_wrapper\n    return fn(*args, **kwargs)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py\", line 758, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/events.py\", line 88, in _run\n    self._context.run(self._callback, *self._args)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 1775, in _run_once\n    handle._run()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/asyncio/base_events.py\", line 539, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py\", line 132, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/Users/pan/anaconda3/lib/python3.7/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_17/"
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }], [(name: "embedding_0.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 5147
#          dims: 128
#        }
#      }
#    }
#    persistable: true, name: "embedding_0.w_0@GRAD"
#    type {
#      type: SELECTED_ROWS
#      selected_rows {
#        data_type: FP32
#        dims: 5147
#        dims: 128
#      }
#    }), (name: "fc_0.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_0.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }), (name: "fc_0.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_0.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#        }
#        lod_level: 0
#      }
#    }), (name: "lstm_0.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "lstm_0.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }), (name: "lstm_0.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 1
#          dims: 896
#        }
#      }
#    }
#    persistable: true, name: "lstm_0.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 1
#          dims: 896
#        }
#      }
#    }), (name: "fc_1.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_1.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#          dims: 512
#        }
#      }
#    }), (name: "fc_1.w_1"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_1.w_1@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }), (name: "fc_1.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_1.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#        }
#        lod_level: 0
#      }
#    }), (name: "lstm_1.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "lstm_1.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }), (name: "lstm_1.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 1
#          dims: 896
#        }
#      }
#    }
#    persistable: true, name: "lstm_1.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 1
#          dims: 896
#        }
#      }
#    }), (name: "fc_2.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_2.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#          dims: 512
#        }
#      }
#    }), (name: "fc_2.w_1"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_2.w_1@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }), (name: "fc_2.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "fc_2.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#        }
#        lod_level: 0
#      }
#    }), (name: "lstm_2.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }
#    persistable: true, name: "lstm_2.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 512
#        }
#      }
#    }), (name: "lstm_2.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 1
#          dims: 896
#        }
#      }
#    }
#    persistable: true, name: "lstm_2.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 1
#          dims: 896
#        }
#      }
#    }), (name: "fc_3.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#          dims: 2
#        }
#      }
#    }
#    persistable: true, name: "fc_3.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 512
#          dims: 2
#        }
#      }
#    }), (name: "fc_3.w_1"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 2
#        }
#      }
#    }
#    persistable: true, name: "fc_3.w_1@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 128
#          dims: 2
#        }
#      }
#    }), (name: "fc_3.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 2
#        }
#      }
#    }
#    persistable: true, name: "fc_3.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 2
#        }
#        lod_level: 0
#      }
#    })])

# %%
def train_test(program, reader):
    count = 0
    feed_var_list = [
        program.global_block().var(var_name) for var_name in feed_order
    ]
    feeder_test = fluid.DataFeeder(feed_list=feed_var_list, place=place)
    test_exe = fluid.Executor(place)
    accumulated = len([avg_cost, accuracy]) * [0]
    for test_data in reader():
        avg_cost_np = test_exe.run(
            program=program,
            feed=feeder_test.feed(test_data),
            fetch_list=[avg_cost, accuracy])
        accumulated = [
            x[0] + x[1][0] for x in zip(accumulated, avg_cost_np)
        ]
        count += 1
    return [x / count for x in accumulated]

# %%
params_dirname = "understand_sentiment_conv.inference.model"
feed_order = ['words', 'label']
pass_num = 1

# %%
def train_loop(main_program):  
    exe.run(fluid.default_startup_program())
    feed_var_list_loop = [
        main_program.global_block().var(var_name) for var_name in feed_order
    ]
    feeder = fluid.DataFeeder(
        feed_list=feed_var_list_loop, place=place)

    test_program = fluid.default_main_program().clone(for_test=True)
    for epoch_id in range(pass_num):
        for step_id, data in enumerate(train_reader()):
            metrics = exe.run(main_program,
                              feed=feeder.feed(data),
                              fetch_list=[avg_cost, accuracy])
         
            avg_cost_test, acc_test = train_test(test_program, test_reader)
            print('Step {0}, Test Loss {1:0.2}, Acc {2:0.2}'.format(
                step_id, avg_cost_test, acc_test))

            print("Step {0}, Epoch {1} Metrics {2}".format(
                step_id, epoch_id, list(map(np.array,
                                            metrics))))
            if step_id == 30:
                if params_dirname is not None:
                    fluid.io.save_inference_model(params_dirname, ["words"],
                                                  prediction, exe)
                return

# %%
train_loop(fluid.default_main_program())
# Out:
# Step 0, Test Loss 0.71, Acc 0.5
# Step 0, Epoch 0 Metrics [array([0.6927068], dtype=float32), array([0.5], dtype=float32)]
# Step 1, Test Loss 0.68, Acc 0.5
# Step 1, Epoch 0 Metrics [array([0.6931808], dtype=float32), array([0.546875], dtype=float32)]
# Step 2, Test Loss 0.68, Acc 0.6
# Step 2, Epoch 0 Metrics [array([0.68124056], dtype=float32), array([0.5078125], dtype=float32)]
# Step 3, Test Loss 0.67, Acc 0.57
# Step 3, Epoch 0 Metrics [array([0.67418545], dtype=float32), array([0.609375], dtype=float32)]
# Step 4, Test Loss 0.67, Acc 0.51
# Step 4, Epoch 0 Metrics [array([0.6721884], dtype=float32), array([0.53125], dtype=float32)]
# Step 5, Test Loss 0.65, Acc 0.66
# Step 5, Epoch 0 Metrics [array([0.6595801], dtype=float32), array([0.546875], dtype=float32)]
# Step 6, Test Loss 0.64, Acc 0.76
# Step 6, Epoch 0 Metrics [array([0.6484457], dtype=float32), array([0.6640625], dtype=float32)]
# Step 7, Test Loss 0.64, Acc 0.63
# Step 7, Epoch 0 Metrics [array([0.65037537], dtype=float32), array([0.7109375], dtype=float32)]
# Step 8, Test Loss 0.63, Acc 0.67
# Step 8, Epoch 0 Metrics [array([0.64937305], dtype=float32), array([0.609375], dtype=float32)]
# Step 9, Test Loss 0.61, Acc 0.77
# Step 9, Epoch 0 Metrics [array([0.6226691], dtype=float32), array([0.671875], dtype=float32)]
# Step 10, Test Loss 0.6, Acc 0.74
# Step 10, Epoch 0 Metrics [array([0.6014201], dtype=float32), array([0.84375], dtype=float32)]
# Step 11, Test Loss 0.59, Acc 0.72
# Step 11, Epoch 0 Metrics [array([0.59876376], dtype=float32), array([0.71875], dtype=float32)]
# Step 12, Test Loss 0.57, Acc 0.73
# Step 12, Epoch 0 Metrics [array([0.59139585], dtype=float32), array([0.671875], dtype=float32)]
# Step 13, Test Loss 0.55, Acc 0.77
# Step 13, Epoch 0 Metrics [array([0.5833155], dtype=float32), array([0.75], dtype=float32)]
# Step 14, Test Loss 0.55, Acc 0.78
# Step 14, Epoch 0 Metrics [array([0.60830945], dtype=float32), array([0.6640625], dtype=float32)]
# Step 15, Test Loss 0.54, Acc 0.77
# Step 15, Epoch 0 Metrics [array([0.57088614], dtype=float32), array([0.765625], dtype=float32)]
# Step 16, Test Loss 0.53, Acc 0.78
# Step 16, Epoch 0 Metrics [array([0.5353235], dtype=float32), array([0.7578125], dtype=float32)]
# Step 17, Test Loss 0.53, Acc 0.75
# Step 17, Epoch 0 Metrics [array([0.52125835], dtype=float32), array([0.8046875], dtype=float32)]
# Step 18, Test Loss 0.51, Acc 0.77
# Step 18, Epoch 0 Metrics [array([0.53560567], dtype=float32), array([0.6953125], dtype=float32)]
# Step 19, Test Loss 0.5, Acc 0.78
# Step 19, Epoch 0 Metrics [array([0.5269475], dtype=float32), array([0.8046875], dtype=float32)]
# Step 20, Test Loss 0.5, Acc 0.77
# Step 20, Epoch 0 Metrics [array([0.5078811], dtype=float32), array([0.7734375], dtype=float32)]
# Step 21, Test Loss 0.49, Acc 0.78
# Step 21, Epoch 0 Metrics [array([0.47448912], dtype=float32), array([0.8125], dtype=float32)]
# Step 22, Test Loss 0.51, Acc 0.76
# Step 22, Epoch 0 Metrics [array([0.48438486], dtype=float32), array([0.796875], dtype=float32)]
# Step 23, Test Loss 0.5, Acc 0.75
# Step 23, Epoch 0 Metrics [array([0.49690428], dtype=float32), array([0.78125], dtype=float32)]
# Step 24, Test Loss 0.47, Acc 0.78
# Step 24, Epoch 0 Metrics [array([0.4629263], dtype=float32), array([0.7890625], dtype=float32)]
# Step 25, Test Loss 0.49, Acc 0.77
# Step 25, Epoch 0 Metrics [array([0.5026718], dtype=float32), array([0.7265625], dtype=float32)]
# Step 26, Test Loss 0.49, Acc 0.77
# Step 26, Epoch 0 Metrics [array([0.52507406], dtype=float32), array([0.7421875], dtype=float32)]
# Step 27, Test Loss 0.48, Acc 0.78
# Step 27, Epoch 0 Metrics [array([0.5492672], dtype=float32), array([0.7265625], dtype=float32)]
# Step 28, Test Loss 0.46, Acc 0.8
# Step 28, Epoch 0 Metrics [array([0.5161584], dtype=float32), array([0.75], dtype=float32)]
# Step 29, Test Loss 0.45, Acc 0.8
# Step 29, Epoch 0 Metrics [array([0.41836327], dtype=float32), array([0.828125], dtype=float32)]
# Step 30, Test Loss 0.47, Acc 0.78
# Step 30, Epoch 0 Metrics [array([0.48943415], dtype=float32), array([0.7734375], dtype=float32)]
